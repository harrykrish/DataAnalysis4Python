# %%
import requests
from requests_oauthlib import OAuth1
import argparse
import urllib.request,json
import datetime
import requests
import os

uauth = OAuth1('CQ0SBNGlDITRbkw2PM84Ug', '7RVaHKptMjqId0CaOSIS_5mnW84',
                  'WmOCoc8PHkdfsDOWv7vnVD2fiOTkstxO', '_yYDR4Kh2qq0tsup11JfS9xzxqU')


ua=OAuth1('WmOCoc8PHkdfsDOWv7vnVD2fiOTkstxO')

requests.get('https://api.yelp.com/oauth2/token',auth=uauth).json()




uauth

# %%
data = urllib.parse.urlencode({
'client_id' : '92p07_JjKyriZTQxAXRiKQ',
'client_secret': 'xJgWoUoy6Y3tGvykSYpi1EmndMnp0Z6TjNiUdhema3e2fyKnXFiOEbiVfhkvIiRA',
        'grant_type'  : 'client_credentials',
})
headers = {
     'content-type': 'application/x-www-form-urlencoded',
 }
response = requests.request('POST', 'https://api.yelp.com/oauth2/token', data=data, headers=headers)
bearer_token = response.json()['access_token']

# %%
headers = {
       'Authorization': 'Bearer %s' % bearer_token
}

# %%
requests.get('https://api.yelp.com/v3/businesses/mission-beach-cafe-san-francisco-4',headers=headers).json()
# Out:
# '8hksaYICws-oRvvbStbG6txLnnmfmxVLYRNJW7WzCAqQJt_sVAJrtbO6z6xSGXgjqXVTSzOOkcnYEW8UdTj-tF-EQo64Fawa_G6UKw_QhV-9ac4ziF2hzOaoRBk7WHYx'

# %%
requestdata=[]
offset=40
data=[]
dataid=[]
businessdata=[]
#Getting data using request api
term='restaurants'
location='Chicago'
for i in range(1,6):
    requestdata.append(requests.get('https://api.yelp.com/v2/search?term='+term+'&location='+location+'&limit=40&offset='+str(offset),auth=uauth,headers=headers).json())
    offset=offset+40

#All the data is stored in single lists (equal to number of times loop is run) - Now putting each element in a list   
for i in range(len(requestdata)):
    for j in range(len(requestdata[i]['businesses'])):
           data.append(requestdata[i]['businesses'][j])

#The data we have is sufficient but this does not have all parameters pertaining to a restaurant or hotel etc.
#We need to get the id of the business and send it to the business request api to get complete data of business
for i in range(len(data)):
    dataid.append(data[i]['id'])

#Here, we fetch the the json file for each business (it has all the parameters)
for i in range(len(dataid)):
    businessdata.append(requests.get('https://api.yelp.com/v3/businesses/'+dataid[i],headers=headers).json())

# %%
# Out:
# 2.5

# %%
#Appending search term to json object
for i in range(len(businessdata)):
    businessdata[i]['term']=term

# %%
#Storing the data in the appropriate folder
import json
import os
foldername=term
directory='Yelp Data'

for i in range(len(businessdata)):
    if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])):
        os.makedirs(directory+'\\'+str(businessdata[i]['location']['country']))
        if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])):
            os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state']))
            if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])):
                os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city']))
                if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)):
                    os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term))
                    with open(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)+'\\'+businessdata[i]['id']+'.json', 'w') as outfile:
                        json.dump(businessdata[i], outfile)
    elif os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])):
        if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])):
            os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state']))
            if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])):
                os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city']))
                if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)):
                    os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term))
                    with open(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)+'\\'+businessdata[i]['id']+'.json', 'w') as outfile:
                        json.dump(businessdata[i], outfile)
        elif os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])):
            if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])):
                os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city']))
                if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)):
                    os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term))
                    with open(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)+'\\'+businessdata[i]['id']+'.json', 'w') as outfile:
                        json.dump(businessdata[i], outfile)
            elif os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])):
                if not os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)):
                    os.makedirs(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term))
                    with open(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)+'\\'+businessdata[i]['id']+'.json', 'w') as outfile:
                        json.dump(businessdata[i], outfile)
                elif os.path.exists(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)):
                     with open(directory+'\\'+str(businessdata[i]['location']['country'])+'\\'+str(businessdata[i]['location']['state'])+'\\'+str(businessdata[i]['location']['city'])+'\\'+str(term)+'\\'+businessdata[i]['id']+'.json', 'w') as outfile:
                        json.dump(businessdata[i], outfile)

# %%
h={
    'X-FullContact-APIKey': '67d9b059fd8d95ae'
    }

# %%
city=[]
for i in range(len(businessdata)):
    city.append(businessdata[i]['location']['city']) 

    
cityunique=[]
cityunique=list(set(city))

# %%
popdata=[]
for i in range(len(cityunique)):
    popdata.append(requests.get('http://api.fullcontact.com/v2/address/locationEnrichment.json?place='+cityunique[i],headers=h).json())

# %%
populationdata=[]
for i in range(len(popdata)):
    if 'locations' in popdata[i].keys():
            for j in range(len(popdata[i]['locations'])):
                if 'city' in popdata[i]['locations'][j].keys() and 'name' in popdata[i]['locations'][j]['state'].keys():
                    populationdata.append(popdata[i]['locations'][j])

# %%
populationdirectory='Population Data'
for i in range(len(populationdata)):
    if not os.path.exists(populationdirectory+'\\'+str(populationdata[i]['country']['code'])):
        os.makedirs(populationdirectory+'\\'+str(populationdata[i]['country']['code']))
        with open(populationdirectory+'\\'+str(populationdata[i]['country']['code'])+'\\'+str(populationdata[i]['city'])+'-'+str(populationdata[i]['state']['name'])+'-'+populationdata[i]['country']['code']+'.json', 'w') as outfile:
            json.dump(populationdata[i], outfile)
    elif os.path.exists(populationdirectory+'\\'+str(populationdata[i]['country']['code'])):
        with open(populationdirectory+'\\'+str(populationdata[i]['country']['code'])+'\\'+str(populationdata[i]['city'])+'-'+str(populationdata[i]['state']['name'])+'-'+populationdata[i]['country']['code']+'.json', 'w') as outfile:
            json.dump(populationdata[i], outfile)

# %%
#Writing data to a csv

# %%
import os
import json
#import sys
#from imp import reload
#reload(sys)
#sys.setdefaultencoding('UTF-8')

mrow=[]
mrow.append('id,name,review_count,price,is_closed,latitude,longitude,city,state,zip_code,country,rating,phone,place_category\n')
path='Yelp Data'
datapath = [os.path.join(root, name)
            for root, dirs, files in os.walk(path)
            for name in files
            if name.endswith((".json", ".jsons"))]

data=[]
for js in datapath:
    with open(js) as json_file:
        data.append(json.load(json_file))

# %%
len(data)
# Out:
# 13057

# %%
for i in range(len(data)):
    if data[i].get("price",'none')!='none':
        mrow.append(str(data[i]['id'])+','+str(data[i]['name'].replace(',',';'))+','+str(data[i]['review_count'])+','+str(data[i]['price'])+','+str(data[i]['is_closed'])+','+str(data[i]['coordinates']['latitude'])+','+str(data[i]['coordinates']['longitude'])+','+str(data[i]['location']['city'])+','+str(data[i]['location']['state'])+','+str(data[i]['location']['zip_code'])+','+str(data[i]['location']['country'])+','+str(data[i]['rating'])+','+str(data[i]['phone'])+','+str(data[i]['term'])+'\n')
    else:
        mrow.append(str(data[i]['id'])+','+str(data[i]['name'].replace(',',';'))+','+str(data[i]['review_count'])+','+str('N/A')+','+str(data[i]['is_closed'])+','+str(data[i]['coordinates']['latitude'])+','+str(data[i]['coordinates']['longitude'])+','+str(data[i]['location']['city'])+','+str(data[i]['location']['state'])+','+str(data[i]['location']['zip_code'])+','+str(data[i]['location']['country'])+','+str(data[i]['rating'])+','+str(data[i]['phone'])+','+str(data[i]['term'])+'\n')

# %%
len(mrow)
# Out:
# 13058

# %%
import csv
#import unicode_literals
with open('C:\\Users\\harikrishna\\Desktop\\YelppData.csv', 'w',encoding='utf-8') as csv_file:
    for a in mrow:
        csv_file.write(a)

# %%
#POpulation data csv
rowdata=[]
rowdata.append('city,population,state_code,state_name,country_code,country_name\n')
path='Population Data'
datapathpop = [os.path.join(root, name)
            for root, dirs, files in os.walk(path)
            for name in files
            if name.endswith((".json", ".jsons"))]

datapopulation=[]
for js in datapathpop:
    with open(js) as json_file:
        datapopulation.append(json.load(json_file))

# %%
datapopulation[0]['state']
# Out:
# {'name': 'South Australia'}

# %%
for i in range(len(datapopulation)):
    if datapopulation[i]['state'].get("code",'none')!='none':
        rowdata.append(str(datapopulation[i]['city'])+','+str(datapopulation[i]['population'])+','+str(datapopulation[i]['state']['code'])+','+str(datapopulation[i]['state']['name'])+','+str(datapopulation[i]['country']['code'])+','+str(datapopulation[i]['country']['name'])+'\n')
    else:
        rowdata.append(str(datapopulation[i]['city'])+','+str(datapopulation[i]['population'])+','+str('N/A')+','+str(datapopulation[i]['state']['name'])+','+str(datapopulation[i]['country']['code'])+','+str(datapopulation[i]['country']['name'])+'\n')

# %%
import csv
#import unicode_literals
with open('C:\\Users\\harikrishna\\Desktop\\PopulationData.csv', 'w',encoding='utf-8') as csv_file:
    for a in rowdata:
        csv_file.write(a)

# %%
#joining population and australia data
df1=pd.read_csv("C:\\Users\\harikrishna\\Desktop\\PopulationData.csv")
df2=pd.read_csv("C:\\Users\\harikrishna\\Desktop\\states_australia.csv")
#print(df1.head())
#print(df2.head())
df3=pd.merge(df1,df2,how='left', left_on=['state_name'],right_on=['State'])
##df3[(df3['state_code'].isnull())]['state_code']
#df3[(df3['state_code'].isnull())]['Abbreviation']
df3.state_code.fillna(df3.Abbreviation, inplace=True)
df3.to_csv("C:\\Users\\harikrishna\\Desktop\\CountryJoinedData.csv")

# %%
import pandas as pd
yelpdata=pd.read_csv("C:\\Users\\harikrishna\\Desktop\\YelppData.csv")
countrydata=pd.read_csv("C:\\Users\\harikrishna\\Desktop\\CountryJoinedData.csv")
print(yelpdata.head())
print(countrydata.head())
# Out:
#                                     id                           name  \
# 0                  a-to-z-travel-acton                  A To Z Travel
# 1  burgmann-college-accomodation-acton  Burgmann College Accomodation
# 2                  telstra-tower-acton                  Telstra Tower
# 3                           alto-acton                           Alto
# 4                        boffins-acton                        Boffins
#
#    review_count price is_closed     latitude    longitude   city state  \
# 0             0   NaN     False  -35.2848358  149.1204529  Acton   ACT
# 1             0   NaN     False    -35.27325    149.11934  Acton   ACT
# 2             3   NaN     False    -35.28022  149.1101227  Acton   ACT
# 3             1  $$$$     False    -35.28022  149.1101227  Acton   ACT
# 4             0   NaN     False  -35.2842407  149.1171875  Acton   ACT
#
#   zip_code country  rating         phone place_category
# 0     2601      AU     0.0  6.126125e+10         hotels
# 1     2601      AU     0.0  6.126126e+10         hotels
# 2     2601      AU     2.5  6.126248e+10         hotels
# 3     2601      AU     2.0  6.126248e+10    restaurants
# 4     2601      AU     0.0  6.126126e+10    restaurants
#    Unnamed: 0       city  population state_code         state_name  \
# 0           0   Adelaide     1074159         SA    South Australia
# 1           1   Armadale        8467        VIC           Victoria
# 2           2   Armadale       12021         WA  Western Australia
# 3           3     Auburn         663         SA    South Australia
# 4           4  Belconnen        3057        ACT           Canberra
#
#   country_code country_name              State Abbreviation
# 0           AU    Australia    South Australia           SA
# 1           AU    Australia           Victoria          VIC
# 2           AU    Australia  Western Australia           WA
# 3           AU    Australia    South Australia           SA
# 4           AU    Australia           Canberra          ACT

# %%
#concatenating column to form keys to join
yelpdata['JoinColumn']=yelpdata['city']+yelpdata['state']+yelpdata['country']
countrydata['JoinColumn']=countrydata['city']+countrydata['state_code']+countrydata['country_code']

# %%
#Filtering only US and AU since i need to join on keys(keys here are formed by concatenating three columns(since in US
#same city name in multiple states))
yelpdataw=yelpdata[(yelpdata['country']=='AU') | (yelpdata['country']=='US') ]

# %%
tempor=pd.merge(yelpdataw,countrydata,how='left', left_on=['JoinColumn'],right_on=['JoinColumn'])
tempor.to_csv("C:\\Users\\harikrishna\\Desktop\\Temp4.csv")

# %%
yelpdataww=yelpdata[(yelpdata['country']!= 'US')& (yelpdata['country']!= 'AU')]
yelpdataww['JoinColumn']=yelpdataww['city']+yelpdataww['country']
#yelpdataww.to_csv("C:\\Users\\harikrishna\\Desktop\\Temp45.csv")
# Out:
# C:\Users\harikrishna\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
countrydata2=countrydata
countrydata2['JoinColumn']=countrydata2['city']+countrydata2['country_code']
countrydata2.to_csv("C:\\Users\\harikrishna\\Desktop\\Hello.csv")

# %%
tempor2=pd.merge(yelpdataww,countrydata2,how='left', left_on=['JoinColumn'],right_on=['JoinColumn'])
tempor2.to_csv("C:\\Users\\harikrishna\\Desktop\\Temp400.csv")

# %%
newdataframe=tempor.append(tempor2)

# %%
newdataframe.to_csv("C:\\Users\\harikrishna\\Desktop\\newdatafram.csv")

# %%
#newdataframe.head(400)

# %%
processed=newdataframe[['id','name','review_count','price','is_closed','latitude','longitude','city_x','state','zip_code','country','rating','phone','place_category','population']]
processed.to_csv("C:\\Users\\harikrishna\\Desktop\\hh.csv")

# %%
#Final data analysis
processed['Price Rating']=processed['price'].str.len()
# Out:
# C:\Users\harikrishna\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
#Timings data
import os
import json
#import sys
#from imp import reload
#reload(sys)
#sys.setdefaultencoding('UTF-8')

rowtiming=[]
rowtiming.append('id,name,review_count,price,is_closed,latitude,longitude,city,state,zip_code,country,rating,phone,place_category\n')
path='Yelp Data'
datapath = [os.path.join(root, name)
            for root, dirs, files in os.walk(path)
            for name in files
            if name.endswith((".json", ".jsons"))]

datatiming=[]
for js in datapath:
    with open(js) as json_file:
        datatiming.append(json.load(json_file))

# %%
datatiming[1000]['hours']
# Out:
# [{'hours_type': 'REGULAR',
#   'is_open_now': True,
#   'open': [{'day': 1, 'end': '2000', 'is_overnight': False, 'start': '1000'},
#    {'day': 2, 'end': '2000', 'is_overnight': False, 'start': '1000'},
#    {'day': 3, 'end': '2000', 'is_overnight': False, 'start': '1000'},
#    {'day': 4, 'end': '2000', 'is_overnight': False, 'start': '1000'},
#    {'day': 5, 'end': '2000', 'is_overnight': False, 'start': '1000'},
#    {'day': 6, 'end': '1400', 'is_overnight': False, 'start': '1030'}]}]

# %%
#requests.get('http://api.fullcontact.com/v2/address/locationEnrichment.json?place=Cambridge%20us',headers=h).json()
path='Yelp Data'
stackques = [os.path.join(root, name)
            for root, dirs, files in os.walk(path)
            for name in files
            if name.endswith((".json", ".jsons"))]

# %%
from datetime import datetime
s1 = '11:30'
s2 = '14:00' # for example
FMT = '%H:%M'
tdelta = datetime.strptime(s2, FMT) - datetime.strptime(s1, FMT)
tdelta.seconds/3600
# Out:
# 2.5

# %%
stackquestions=[]
for js in stackques:
    with open(js) as json_file:
        stackquestions.append(json.load(json_file))

# %%
city=[]
for i in range(len(stackquestions)):
    city.append(stackquestions[i]['location']['city'])

# %%
cityunique=list(set(city))

# %%
len(cityunique)
# Out:
# 273

# %%
nn='San Francisco'

# %%
temppp=[]
ll=[]
temppp.append(requests.get('http://api.fullcontact.com/v2/address/locationEnrichment.json?place='+location,headers=h).json())

# %%
temppp[0]['locations'][1]
# Out:
# {'city': 'Sydney',
#  'continent': 'North America',
#  'country': {'code': 'CA', 'name': 'Canada'},
#  'normalizedLocation': 'Sydney, Nova Scotia, Canada',
#  'population': 105968,
#  'state': {'name': 'Nova Scotia'}}

# %%
dd=[]
for i in range(len(temppp)):
    for j in range(len(temppp[i]['locations'])):
        dd.append(temppp[i]['locations'][j])

dd[1]
# Out:
# {'city': 'San Francisco',
#  'continent': 'Asia',
#  'country': {'code': 'PH', 'name': 'Philippines'},
#  'county': 'Province Of Nueva Ecija',
#  'normalizedLocation': 'San Francisco, Central Luzon, Philippines',
#  'population': 19570,
#  'state': {'name': 'Central Luzon'}}

# %%
#for i in range(1,15):
requests.get('https://api.yelp.com/v2/search?term=attractions&location=San Jose&limit=40&offset=40',auth=uauth,headers=headers).json()
# Out:
# {'businesses': [{'categories': [['Botanical Gardens', 'gardens'],
#     ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-408-741-4994',
#    'id': 'hakone-estate-and-gardens-saratoga',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2FJjGLOVLZefzaZ2MUHqSw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['21000 Big Basin Way'],
#     'city': 'Saratoga',
#     'coordinate': {'latitude': 37.2541121, 'longitude': -122.0392844},
#     'country_code': 'US',
#     'display_address': ['21000 Big Basin Way', 'Saratoga, CA 95070'],
#     'geo_accuracy': 8.0,
#     'postal_code': '95070',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hakone-estate-and-gardens-saratoga?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hakone Estate & Gardens',
#    'phone': '4087414994',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 342,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/l9DmsFRM2Gj7Dar7QhKZ-A/ms.jpg',
#    'snippet_text': 'My husband and I had our wedding ceremony and reception here earlier this month and it was perfect. Tony, the event coordinator, and Christine, his...',
#    'url': 'https://www.yelp.com/biz/hakone-estate-and-gardens-saratoga?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Amusement Parks', 'amusementparks']],
#    'display_phone': '+1-408-988-1776',
#    'id': 'californias-great-america-santa-clara',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RoaYC17f21Je0qMjPhR0Ug/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['4701 Great America Pkwy'],
#     'city': 'Santa Clara',
#     'coordinate': {'latitude': 37.395613, 'longitude': -121.972017},
#     'country_code': 'US',
#     'display_address': ['4701 Great America Pkwy', 'Santa Clara, CA 95054'],
#     'geo_accuracy': 9.5,
#     'postal_code': '95054',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/californias-great-america-santa-clara?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "California's Great America",
#    'phone': '4089881776',
#    'rating': 3.0,
#    'rating_img_url': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/34bc8086841c/ico/stars/v1/stars_3.png',
#    'rating_img_url_large': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/e8b5b79d37ed/ico/stars/v1/stars_large_3.png',
#    'rating_img_url_small': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/902abeed0983/ico/stars/v1/stars_small_3.png',
#    'review_count': 1057,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/vH8bTAX_LQijXu1otT3eYQ/ms.jpg',
#    'snippet_text': "Love this park!  I'm a long time season pass holder.  If you have not been in the last few years... or even in the last 10 years.... it is time to return!!...",
#    'url': 'https://www.yelp.com/biz/californias-great-america-santa-clara?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Skating Rinks', 'skatingrinks'],
#     ['Fitness & Instruction', 'fitness'],
#     ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-408-279-6000',
#    'id': 'sharks-ice-at-san-jose-san-jose',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ccDZeIbehqnIAPXjI6M4mg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1500 S 10th St'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.31997, 'longitude': -121.86426},
#     'country_code': 'US',
#     'display_address': ['1500 S 10th St', 'Fairgrounds', 'San Jose, CA 95112'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Fairgrounds'],
#     'postal_code': '95112',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/sharks-ice-at-san-jose-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Sharks Ice At San Jose',
#    'phone': '4082796000',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 170,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/assets/srv0/yelp_styleguide/bf5ff8a79310/assets/img/default_avatars/user_medium_square.png',
#    'snippet_text': "We visited their shop to purchase ice skating shoes for our daughter.\nThey have many varieties of shoes but it was kind of hard to find my daughter's...",
#    'url': 'https://www.yelp.com/biz/sharks-ice-at-san-jose-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Gyms', 'gyms'],
#     ['Sports Clubs', 'sports_clubs'],
#     ['Trainers', 'healthtrainers']],
#    'display_phone': '+1-408-490-2164',
#    'id': 'city-sports-club-san-jose-5',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5ZfISpnb9GNBJR6IOm-_cg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['610 Newhall Dr'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3494535465614,
#      'longitude': -121.920884579064},
#     'country_code': 'US',
#     'display_address': ['610 Newhall Dr',
#      'North San Jose',
#      'San Jose, CA 95110'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['North San Jose'],
#     'postal_code': '95110',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/city-sports-club-san-jose-5?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'City Sports Club',
#    'phone': '4084902164',
#    'rating': 3.0,
#    'rating_img_url': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/34bc8086841c/ico/stars/v1/stars_3.png',
#    'rating_img_url_large': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/e8b5b79d37ed/ico/stars/v1/stars_large_3.png',
#    'rating_img_url_small': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/902abeed0983/ico/stars/v1/stars_small_3.png',
#    'review_count': 240,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/N_mHZUa8d9g_cnmMw9D-bw/ms.jpg',
#    'snippet_text': 'Among the 3 City Sports locations that I frequent, this location off Coleman Ave is my favorite. Management does a great job of keeping this place clean and...',
#    'url': 'https://www.yelp.com/biz/city-sports-club-san-jose-5?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Event Planning & Services', 'eventservices']],
#    'display_phone': '+1-408-295-9600',
#    'id': 'team-san-jose-san-jose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UFQ0af2zJ-uxWZ5t0lFQjg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['408 Almaden Ave'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.32778, 'longitude': -121.8886038},
#     'country_code': 'US',
#     'display_address': ['408 Almaden Ave', 'Downtown', 'San Jose, CA 95110'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95110',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/team-san-jose-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Team San Jose',
#    'phone': '4082959600',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 3,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/SWx5BX4_x_JTV5GoGMtT4Q/ms.jpg',
#    'snippet_text': 'Team San Jose did a wonderful job catering and working an event my organization held earlier this week. Everyone raved about the food and it was totally an...',
#    'url': 'https://www.yelp.com/biz/team-san-jose-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Local Flavor', 'localflavor']],
#    'id': 'communications-hill-san-jose-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ATCevAaOro8xAgSupCz3LA/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': [],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.2819084724397,
#      'longitude': -121.856194381481},
#     'country_code': 'US',
#     'display_address': ['Fairgrounds', 'San Jose, CA 95136'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Fairgrounds'],
#     'postal_code': '95136',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/communications-hill-san-jose-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Communications Hill',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 135,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/RuEDTgVYdnmULtggO9rL6g/ms.jpg',
#    'snippet_text': 'Wow! What a great work out. I did all 272 steps 3x and felt fine the next day. But the day after that, my calves were on FIRE! \nI was looking for something...',
#    'url': 'https://www.yelp.com/biz/communications-hill-san-jose-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Festivals', 'festivals']],
#    'display_phone': '+1-408-293-9292',
#    'id': 'san-jose-obon-odori-san-jose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JcyczYYRiN36qoykPofoiQ/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['640 N 5th St'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.34987, 'longitude': -121.89455},
#     'country_code': 'US',
#     'display_address': ['640 N 5th St', 'Downtown', 'San Jose, CA 95112'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95112',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/san-jose-obon-odori-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'San Jose Obon Odori',
#    'phone': '4082939292',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 75,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/fm-JVCSOKXNqD3LZy1AQog/ms.jpg',
#    'snippet_text': 'REVIEWER # 75\n\nThis year was my first time experiencing the 2016 San Jose Obon Festival and I have to say it was a BLAST!\n\nI first found out about this...',
#    'url': 'https://www.yelp.com/biz/san-jose-obon-odori-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Gyms', 'gyms'], ['Trainers', 'healthtrainers']],
#    'display_phone': '+1-408-490-3019',
#    'id': '24-hour-fitness-san-jose-18',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0cH7QiwnvyNF8hP8GCF7Pg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1610 Crane Ct'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.37117, 'longitude': -121.91142},
#     'country_code': 'US',
#     'display_address': ['1610 Crane Ct',
#      'North San Jose',
#      'San Jose, CA 95112'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['North San Jose'],
#     'postal_code': '95112',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/24-hour-fitness-san-jose-18?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': '24 Hour Fitness',
#    'phone': '4084903019',
#    'rating': 3.0,
#    'rating_img_url': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/34bc8086841c/ico/stars/v1/stars_3.png',
#    'rating_img_url_large': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/e8b5b79d37ed/ico/stars/v1/stars_large_3.png',
#    'rating_img_url_small': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/902abeed0983/ico/stars/v1/stars_small_3.png',
#    'review_count': 613,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/saHoQC0fHexTOgkklxMbSw/ms.jpg',
#    'snippet_text': "Great gym. So far I don't have any complaints and I've been going here for 4 months now.  But then again, I do go at midnight when it's a ghost town and...",
#    'url': 'https://www.yelp.com/biz/24-hour-fitness-san-jose-18?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Gyms', 'gyms'],
#     ['Sports Clubs', 'sports_clubs'],
#     ['Trainers', 'healthtrainers']],
#    'display_phone': '+1-408-273-7185',
#    'id': 'city-sports-club-san-jose-4',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gSntT7VXrz4xURBcFoXlqg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1045 E Brokaw Rd'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.382899011599,
#      'longitude': -121.897376775742},
#     'country_code': 'US',
#     'display_address': ['1045 E Brokaw Rd',
#      'North Valley',
#      'San Jose, CA 95131'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['North Valley'],
#     'postal_code': '95131',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/city-sports-club-san-jose-4?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'City Sports Club',
#    'phone': '4082737185',
#    'rating': 2.5,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c7fb9aff59f9/ico/stars/v1/stars_2_half.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/d63e3add9901/ico/stars/v1/stars_large_2_half.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/8e8633e5f8f0/ico/stars/v1/stars_small_2_half.png',
#    'review_count': 287,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/AQxg3kHm9KUgSTEneN-m5A/ms.jpg',
#    'snippet_text': "Perhaps anyone who B I T C H E S about something at the gym, shouldn't be at the gym.\n\nJust go in, work-out & leave...",
#    'url': 'https://www.yelp.com/biz/city-sports-club-san-jose-4?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Bowling', 'bowling'],
#     ['Diners', 'diners'],
#     ['Sports Bars', 'sportsbars']],
#    'display_phone': '+1-408-453-5555',
#    'id': '4th-street-bowl-san-jose',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W-yn9G2PZuxLJ3ZOzKbkvQ/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['1441 N 4th St'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3636191189365,
#      'longitude': -121.907712212358},
#     'country_code': 'US',
#     'display_address': ['1441 N 4th St',
#      'North San Jose',
#      'San Jose, CA 95112'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['North San Jose'],
#     'postal_code': '95112',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/4th-street-bowl-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': '4th Street Bowl',
#    'phone': '4084535555',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 288,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/byOBJdssSQudjuBJZL7LTA/ms.jpg',
#    'snippet_text': 'Came here a few nights ago with a fairly big group of people (10~12 people). We initially came in because it was cheaper than most places ($5.50/game per...',
#    'url': 'https://www.yelp.com/biz/4th-street-bowl-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-408-226-3200',
#    'id': 'dolce-hayes-mansion-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AxIqlbRREIJFTdlAmF_hoA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['200 Edenvale Ave'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.262356, 'longitude': -121.820315},
#     'country_code': 'US',
#     'display_address': ['200 Edenvale Ave',
#      'Blossom Valley',
#      'San Jose, CA 95136'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Blossom Valley'],
#     'postal_code': '95136',
#     'state_code': 'CA'},
#    'menu_date_updated': 1473015121,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/dolce-hayes-mansion-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Dolce Hayes Mansion',
#    'phone': '4082263200',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 337,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/lHAJgMy76dtQQ2EKqIR8vQ/ms.jpg',
#    'snippet_text': 'We stayed at Hayes during our wedding.  Although we got married off site, Hayes Mansion allowed us to take our wedding photos on site and we also used the...',
#    'url': 'https://www.yelp.com/biz/dolce-hayes-mansion-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['DJs', 'djs']],
#    'display_phone': '+1-408-561-1597',
#    'id': 'rhythm-gs-entertainment-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lDUwtvwiAC9loQoWmwTkEA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': [],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.27238, 'longitude': -121.8539},
#     'country_code': 'US',
#     'display_address': ['Blossom Valley', 'San Jose, CA 95136'],
#     'geo_accuracy': 5.0,
#     'neighborhoods': ['Blossom Valley'],
#     'postal_code': '95136',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/rhythm-gs-entertainment-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "Rhythm G's Entertainment",
#    'phone': '4085611597',
#    'rating': 5.0,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/f1def11e4e79/ico/stars/v1/stars_5.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/22affc4e6c38/ico/stars/v1/stars_large_5.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/c7623205d5cd/ico/stars/v1/stars_small_5.png',
#    'review_count': 16,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/Dp2lvDjxr2M9jMlDpa0u3g/ms.jpg',
#    'snippet_text': "Grady & Geeta are awesome! We recently used Rhythm G for our daughter's 10th Birthday. They were terrific. The dance party was a super hit among both kids...",
#    'url': 'https://www.yelp.com/biz/rhythm-gs-entertainment-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-408-282-8800',
#    'id': 'four-points-by-sheraton-san-jose-downtown-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YCCp7oXbhaWBJHEd4V-O3A/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['211 S. First Street'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.33215, 'longitude': -121.88805},
#     'country_code': 'US',
#     'display_address': ['211 S. First Street',
#      'Downtown',
#      'San Jose, CA 95113'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95113',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/four-points-by-sheraton-san-jose-downtown-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Four Points by Sheraton San Jose Downtown',
#    'phone': '4082828800',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 240,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/8OpNYxJLREAHDZuWfrOh2w/ms.jpg',
#    'snippet_text': "I stayed here with 2 teenage daughters for my oldest daughter's freshman orientation at SJSU. \nSo easy to find. Cute clean area. Was greeted by very...",
#    'url': 'https://www.yelp.com/biz/four-points-by-sheraton-san-jose-downtown-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Races & Competitions', 'races']],
#    'id': 'rock-n-roll-half-marathon-san-jose-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kdj8dZ9dLePfa5w5J5lH-A/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': [],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.33239, 'longitude': -121.89033},
#     'country_code': 'US',
#     'display_address': ['Downtown', 'San Jose, CA 95113'],
#     'geo_accuracy': 5.0,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95113',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/rock-n-roll-half-marathon-san-jose-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Rock n Roll Half Marathon San Jose',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 200,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/NFVy7LcMqJYceIYtGWuIMw/ms.jpg',
#    'snippet_text': 'I ran this half marathon last weekend.\nEverything was very well organised, right from pre race communications to packet pickup to the race and results.\nI...',
#    'url': 'https://www.yelp.com/biz/rock-n-roll-half-marathon-san-jose-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Gyms', 'gyms'], ['Yoga', 'yoga'], ['Pilates', 'pilates']],
#    'display_phone': '+1-408-363-1010',
#    'id': 'forma-gym-san-jose',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TUKEkbG6au7XcJjpNKx4bQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['5434 Thornwood Dr'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.2546005, 'longitude': -121.8601532},
#     'country_code': 'US',
#     'display_address': ['5434 Thornwood Dr',
#      'Blossom Valley',
#      'San Jose, CA 95123'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Blossom Valley'],
#     'postal_code': '95123',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/forma-gym-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Forma Gym',
#    'phone': '4083631010',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 38,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/YOftTGGf3y5-g-NmefNSLw/ms.jpg',
#    'snippet_text': 'I joined this club eight years ago. Since then, it has changed hands twice. This is important for a silly reason: the name. When I first saw the new name...',
#    'url': 'https://www.yelp.com/biz/forma-gym-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Lounges', 'lounges'],
#     ['American (Traditional)', 'tradamerican'],
#     ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-408-291-0677',
#    'id': 'loft-bar-and-bistro-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jrGRCpxMkuUEl7vuZ3XEnA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['90 S 2nd St'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.335222948704, 'longitude': -121.8882245193},
#     'country_code': 'US',
#     'display_address': ['90 S 2nd St', 'Downtown', 'San Jose, CA 95113'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95113',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472594447,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/loft-bar-and-bistro-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Loft Bar and Bistro',
#    'phone': '4082910677',
#    'rating': 3.0,
#    'rating_img_url': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/34bc8086841c/ico/stars/v1/stars_3.png',
#    'rating_img_url_large': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/e8b5b79d37ed/ico/stars/v1/stars_large_3.png',
#    'rating_img_url_small': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/902abeed0983/ico/stars/v1/stars_small_3.png',
#    'review_count': 1006,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/7GWUWE5NkoJEjM5POtue_w/ms.jpg',
#    'snippet_text': 'I normally work nights and weekends so when I do go out I do it big! When I was introduced to Loft I fell in love... Good food, Amazing music and a very...',
#    'url': 'https://www.yelp.com/biz/loft-bar-and-bistro-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Casinos', 'casinos']],
#    'display_phone': '+1-408-244-3333',
#    'id': 'casino-m8trix-san-jose-2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FP7Zxb_jrZjcmBZuMoDOpA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1887 Matrix Blvd'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3714532065156,
#      'longitude': -121.91837310791},
#     'country_code': 'US',
#     'display_address': ['1887 Matrix Blvd',
#      'North San Jose',
#      'San Jose, CA 95110'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['North San Jose'],
#     'postal_code': '95110',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/casino-m8trix-san-jose-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Casino M8trix',
#    'phone': '4082443333',
#    'rating': 2.5,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c7fb9aff59f9/ico/stars/v1/stars_2_half.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/d63e3add9901/ico/stars/v1/stars_large_2_half.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/8e8633e5f8f0/ico/stars/v1/stars_small_2_half.png',
#    'review_count': 383,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/eIUNxHOOxBWdl0KdRnomWQ/ms.jpg',
#    'snippet_text': 'We had such a fun time singing kareoke, eating great food and drinking to our hearts content while having a terrific view of downtown SJ. We had a very...',
#    'url': 'https://www.yelp.com/biz/casino-m8trix-san-jose-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Parks', 'parks'],
#     ['Hiking', 'hiking'],
#     ['Mountain Biking', 'mountainbiking']],
#    'display_phone': '+1-408-867-2952',
#    'id': 'castle-rock-state-park-los-gatos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ok0gdNdwoZzDyEgU9iRCYg/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['15000 Skyline Blvd'],
#     'city': 'Los Gatos',
#     'coordinate': {'latitude': 37.230769782945,
#      'longitude': -122.095757814099},
#     'country_code': 'US',
#     'display_address': ['15000 Skyline Blvd', 'Los Gatos, CA 95032'],
#     'geo_accuracy': 9.5,
#     'postal_code': '95032',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/castle-rock-state-park-los-gatos?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Castle Rock State Park',
#    'phone': '4088672952',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 288,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/N5-Y3YCNL1g_16ufYIE-GA/ms.jpg',
#    'snippet_text': "Ahhh! Gorgeous views with minimal work put in? That's this Yelper's kind of hiking spot! Castle Rock is a great spot for hikers experienced and green alike...",
#    'url': 'https://www.yelp.com/biz/castle-rock-state-park-los-gatos?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Festivals', 'festivals']],
#    'id': 'tet-festival-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IxsfqZ1kx6DVObS9-Vxh0Q/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['344 Tully Road'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.30012, 'longitude': -121.85155},
#     'country_code': 'US',
#     'display_address': ['344 Tully Road', 'Fairgrounds', 'San Jose, CA 95111'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Fairgrounds'],
#     'postal_code': '95111',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/tet-festival-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Tet Festival',
#    'rating': 2.5,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c7fb9aff59f9/ico/stars/v1/stars_2_half.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/d63e3add9901/ico/stars/v1/stars_large_2_half.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/8e8633e5f8f0/ico/stars/v1/stars_small_2_half.png',
#    'review_count': 8,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/hCTbnvy7Vcmk2JTWXcLqGA/ms.jpg',
#    'snippet_text': 'As my Viet homies would say Chúc Mung Nam Moi!?!\n\nDriving home on 101 I noticed a sign for the Tet Festival, kind of intriguing so I was like what heck...',
#    'url': 'https://www.yelp.com/biz/tet-festival-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Local Flavor', 'localflavor']],
#    'id': 'hot-hot-hot-elite-event-fahrenheit-san-jose',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rBAen2lpeNCfX6waajLXWQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['99 E San Fernando St'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3353348, 'longitude': -121.8872833},
#     'country_code': 'US',
#     'display_address': ['99 E San Fernando St',
#      'Downtown',
#      'San Jose, CA 95113'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95113',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hot-hot-hot-elite-event-fahrenheit-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hot, Hot, Hot Elite Event @ Fahrenheit',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 38,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/YChFLSLThPAxMIJ0FZTD0g/ms.jpg',
#    'snippet_text': 'Very fun event at a place that brings back memories for a lot of reasons including a very special 30th birthday. \n\nHad a fun time watching Sal/Lee at the...',
#    'url': 'https://www.yelp.com/biz/hot-hot-hot-elite-event-fahrenheit-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-408-437-0900',
#    'id': 'alura-inn-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ELbsgmijixZ5hSg1wEllsw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1378 Oakland Road'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3718414, 'longitude': -121.8930969},
#     'country_code': 'US',
#     'display_address': ['1378 Oakland Road',
#      'North Valley',
#      'San Jose, CA 95112'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['North Valley'],
#     'postal_code': '95112',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/alura-inn-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Alura Inn',
#    'phone': '4084370900',
#    'rating': 2.5,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c7fb9aff59f9/ico/stars/v1/stars_2_half.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/d63e3add9901/ico/stars/v1/stars_large_2_half.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/8e8633e5f8f0/ico/stars/v1/stars_small_2_half.png',
#    'review_count': 76,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/Cpg_97OFNM7h__8YCSkTKQ/ms.jpg',
#    'snippet_text': 'I was searching for a hotel in San Jose at a decent price and came across the Alura. I read some reviews and keeping in mind this is a 2 star hotel I booked...',
#    'url': 'https://www.yelp.com/biz/alura-inn-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Cinema', 'movietheaters']],
#    'display_phone': '+1-408-265-7373',
#    'id': 'cinelux-almaden-cinema-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ib1J82bjD39g-oqseWR-KQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2306 Almaden Rd'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.2915599, 'longitude': -121.87928},
#     'country_code': 'US',
#     'display_address': ['2306 Almaden Rd',
#      'Willow Glen',
#      'San Jose, CA 95125'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Willow Glen'],
#     'postal_code': '95125',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/cinelux-almaden-cinema-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'CineLux Almaden Cinema',
#    'phone': '4082657373',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 205,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/iSwd5Wz0ZBbvW5I4XgQJGw/ms.jpg',
#    'snippet_text': "CineLux is place is the best VALUE in town! TIckets are only $6 matinee, and $10 after 6PM...Can't forget about $5.50 Tuesdays too!\n\nIt's definitely a...",
#    'url': 'https://www.yelp.com/biz/cinelux-almaden-cinema-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Gyms', 'gyms'], ['Martial Arts', 'martialarts']],
#    'display_phone': '+1-408-239-0881',
#    'id': 'smash-gyms-san-jose',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/U9BkJosPwORVmGrA3PXVkw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2268 Quimby Rd', 'Ste C'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3224446, 'longitude': -121.8092394},
#     'country_code': 'US',
#     'display_address': ['2268 Quimby Rd',
#      'Ste C',
#      'East San Jose',
#      'San Jose, CA 95122'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['East San Jose'],
#     'postal_code': '95122',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/smash-gyms-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Smash Gyms',
#    'phone': '4082390881',
#    'rating': 5.0,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/f1def11e4e79/ico/stars/v1/stars_5.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/22affc4e6c38/ico/stars/v1/stars_large_5.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/c7623205d5cd/ico/stars/v1/stars_small_5.png',
#    'review_count': 48,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/LtyCQolKr1MThIXUH2zpOg/ms.jpg',
#    'snippet_text': 'This review is for the Smash Gyms, San Jose location off Quimby Rd. \n\n\nThe kickboxing program is for all skill levels. They have gloves at the gym to use if...',
#    'url': 'https://www.yelp.com/biz/smash-gyms-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Casinos', 'casinos'], ['Lounges', 'lounges']],
#    'display_phone': '+1-408-451-8888',
#    'id': 'bay-101-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UGmyr5Q9_Z17B9vmERjc9g/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1801 Bering Dr'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3735, 'longitude': -121.91485},
#     'country_code': 'US',
#     'display_address': ['1801 Bering Dr',
#      'North San Jose',
#      'San Jose, CA 95112'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['North San Jose'],
#     'postal_code': '95112',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/bay-101-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Bay 101',
#    'phone': '4084518888',
#    'rating': 3.0,
#    'rating_img_url': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/34bc8086841c/ico/stars/v1/stars_3.png',
#    'rating_img_url_large': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/e8b5b79d37ed/ico/stars/v1/stars_large_3.png',
#    'rating_img_url_small': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/902abeed0983/ico/stars/v1/stars_small_3.png',
#    'review_count': 173,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Psyk2Wkx-vEKEPBlP-CKFw/ms.jpg',
#    'snippet_text': 'I KID YOU NOT!!! Best Pho and fried rice and calamari ever ever ever!! Clean, fresh and price is reasonable. I do not gamble but I definitely come here once...',
#    'url': 'https://www.yelp.com/biz/bay-101-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-408-280-5300',
#    'id': 'hotel-elan-san-jose-san-jose',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NvDIycCxHn6l0CEGBl5xeQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1215 S 1st Street'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3182828, 'longitude': -121.8761139},
#     'country_code': 'US',
#     'display_address': ['1215 S 1st Street',
#      'Fairgrounds',
#      'San Jose, CA 95110'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Fairgrounds'],
#     'postal_code': '95110',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hotel-elan-san-jose-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hotel Elan San Jose',
#    'phone': '4082805300',
#    'rating': 2.0,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/b561c24f8341/ico/stars/v1/stars_2.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c00926ee5dcb/ico/stars/v1/stars_large_2.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a6210baec261/ico/stars/v1/stars_small_2.png',
#    'review_count': 44,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/dmz51e99OsGHp5UgGBOE0Q/ms.jpg',
#    'snippet_text': "Stayed here again since it's so conveniently close to Kelley Park. It's not our first time staying at Elan so we know what to expect. In the past we heard...",
#    'url': 'https://www.yelp.com/biz/hotel-elan-san-jose-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Bikes', 'bikes'],
#     ['Bike Rentals', 'bikerentals'],
#     ['Bike Repair/Maintenance', 'bike_repair_maintenance']],
#    'display_phone': '+1-408-998-1618',
#    'id': 'bicycle-express-san-jose',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_QX503A18aGiHqOh7fqxkg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['131 E William St'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3298408, 'longitude': -121.8825362},
#     'country_code': 'US',
#     'display_address': ['131 E William St', 'Downtown', 'San Jose, CA 95112'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95112',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/bicycle-express-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Bicycle Express',
#    'phone': '4089981618',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 292,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/DUfNc2jLGWSBpOPg6TOxPA/ms.jpg',
#    'snippet_text': 'Jose and Nick are the two nicest people when it comes to not knowing what to say or know anything for that matter, in areas I can only assume is their...',
#    'url': 'https://www.yelp.com/biz/bicycle-express-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Personal Shopping', 'personal_shopping'],
#     ['Cultural Center', 'culturalcenter'],
#     ['Religious Items', 'religiousitems']],
#    'deals': [{'additional_restrictions': 'Promotion lasts for 1 year from date of purchase. After that period, your voucher is redeemable for the amount you paid. Not valid as payment for Eat24 purchases. Not valid with other vouchers, certificates, or offers. Must be 21 or older. Valid only for in-stock items. Only 1 voucher(s) can be purchased and redeemed per person. Must use in a single visit. Up to 1 can be purchased as gifts for others. Subject to the <a target="_blank" href="https://www.yelp.com/tos/general_b2c_us_20120911">General Terms</a>.',
#      'currency_code': 'USD',
#      'id': 'f1c-hRRt31m8Mq4PNZc-uw',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/dphoto/fTgkoLNYCrFdGlohm3114Q/m.jpg',
#      'is_popular': True,
#      'options': [{'formatted_original_price': '$100',
#        'formatted_price': '$75',
#        'is_quantity_limited': False,
#        'original_price': 10000,
#        'price': 7500,
#        'purchase_url': 'https://www.yelp.com/checkout/deal/w-mYPo5a5wvypv_vjY_4Bw?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#        'title': '$75 for $100'}],
#      'time_start': 1466292739,
#      'title': '$75 for $100',
#      'url': 'https://www.yelp.com/deals/botanica-el-trebol-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#      'what_you_get': 'You get a voucher redeemable for $100 at Botanica El Trebol.\nPrint out your voucher, or redeem on your phone with the <a href="https://www.yelp.com/mobile?source=deal_marketing">Yelp app</a>.'}],
# ...
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['4149 Littleworth Way'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.31004, 'longitude': -121.76917},
#     'country_code': 'US',
#     'display_address': ['4149 Littleworth Way',
#      'Evergreen',
#      'San Jose, CA 95135'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Evergreen'],
#     'postal_code': '95135',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/fantasy-jumperz-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Fantasy Jumperz',
#    'phone': '4088412815',
#    'rating': 5.0,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/f1def11e4e79/ico/stars/v1/stars_5.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/22affc4e6c38/ico/stars/v1/stars_large_5.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/c7623205d5cd/ico/stars/v1/stars_small_5.png',
#    'review_count': 109,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/FSMEMLMTsCqEVpOy7Ag-aA/ms.jpg',
#    'snippet_text': 'Whenever there is a special UFC fight, our family would get together to have a little family party. This year we wanted to spoil the children so we rented a...',
#    'url': 'https://www.yelp.com/biz/fantasy-jumperz-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Parks', 'parks']],
#    'display_phone': '+1-408-730-7751',
#    'id': 'ortega-park-sunnyvale',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ehkbRQZp3ETuDcqeOUApPQ/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['636 Harrow Way'],
#     'city': 'Sunnyvale',
#     'coordinate': {'latitude': 37.3429054, 'longitude': -122.0248395},
#     'country_code': 'US',
#     'display_address': ['636 Harrow Way', 'Sunnyvale, CA 94087'],
#     'geo_accuracy': 8.0,
#     'postal_code': '94087',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/ortega-park-sunnyvale?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Ortega Park',
#    'phone': '4087307751',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 95,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/P-DDq8r1hL0GIHK7KrFQMQ/ms.jpg',
#    'snippet_text': 'This park, if you are in the neighborhood or close by, is definitely a wonderful and fantastic park for all ages.  The only negative things about this park...',
#    'url': 'https://www.yelp.com/biz/ortega-park-sunnyvale?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Performing Arts', 'theater']],
#    'display_phone': '+1-408-295-4200',
#    'id': 'city-lights-theater-company-san-jose',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z6qkttOWnZUc188WsdYdOA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['529 S 2nd St'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.3284, 'longitude': -121.8838},
#     'country_code': 'US',
#     'display_address': ['529 S 2nd St', 'Downtown', 'San Jose, CA 95112'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95112',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/city-lights-theater-company-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'City Lights Theater Company',
#    'phone': '4082954200',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 126,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/i_F6FoJE-8keMsvxHT56jQ/ms.jpg',
#    'snippet_text': 'As big fans of local theater companies, City Lights is one of our favorites.   We have enjoyed every production, the theater is intimate, not a bad seat in...',
#    'url': 'https://www.yelp.com/biz/city-lights-theater-company-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-408-435-8800',
#    'id': 'la-quinta-inn-and-suites-san-jose-airport-san-jose',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6BIhVpas44EA89SMe4R-Ng/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2585 Seaboard Ave'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.378175, 'longitude': -121.939132},
#     'country_code': 'US',
#     'display_address': ['2585 Seaboard Ave',
#      'North San Jose',
#      'San Jose, CA 95131'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['North San Jose'],
#     'postal_code': '95131',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/la-quinta-inn-and-suites-san-jose-airport-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'La Quinta Inn & Suites San Jose Airport',
#    'phone': '4084358800',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 79,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/M6qwvHdzparkADNncymu4Q/ms.jpg',
#    'snippet_text': 'Stayed here during Labor Day weekend for a staycation with my family. \nThe place was nice and clean. \nbreakfast... typical breakfast but not that...',
#    'url': 'https://www.yelp.com/biz/la-quinta-inn-and-suites-san-jose-airport-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Psychics & Astrologers', 'psychic_astrology'],
#     ['Nutritionists', 'nutritionists'],
#     ['Life Coach', 'lifecoach']],
#    'display_phone': '+1-831-239-0877',
#    'id': 'wisdom-healing-tarot-santa-cruz-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SlaYr4dShtlx3tsRMJX4pQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1125 Pacific Ave'],
#     'city': 'Santa Cruz',
#     'coordinate': {'latitude': 36.9724494, 'longitude': -122.0257064},
#     'country_code': 'US',
#     'display_address': ['1125 Pacific Ave', 'Santa Cruz, CA 95060'],
#     'geo_accuracy': 9.5,
#     'postal_code': '95060',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/wisdom-healing-tarot-santa-cruz-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Wisdom Healing Tarot',
#    'phone': '8312390877',
#    'rating': 5.0,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/f1def11e4e79/ico/stars/v1/stars_5.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/22affc4e6c38/ico/stars/v1/stars_large_5.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/c7623205d5cd/ico/stars/v1/stars_small_5.png',
#    'review_count': 10,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/_nkM6Wgzxu7WxKmrKtlt3w/ms.jpg',
#    'snippet_text': 'Marcia is a warm and engaging tarot reader.  Her readings go beyond the typical and mundane, into deeper areas of insight.\nYou will be able to explore your...',
#    'url': 'https://www.yelp.com/biz/wisdom-healing-tarot-santa-cruz-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Tours', 'tours']],
#    'display_phone': '+1-831-466-0206',
#    'id': 'segway-santa-cruz-tours-santa-cruz',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G6wiSn4X3TZ6_qPgM76UmA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['302 Pacific Ave'],
#     'city': 'Santa Cruz',
#     'coordinate': {'latitude': 36.96497, 'longitude': -122.0258},
#     'country_code': 'US',
#     'display_address': ['302 Pacific Ave', 'Santa Cruz, CA 95060'],
#     'geo_accuracy': 8.0,
#     'postal_code': '95060',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/segway-santa-cruz-tours-santa-cruz?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Segway Santa Cruz Tours',
#    'phone': '8314660206',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 46,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Ujp2vUdBRMiI43LBopgI1Q/ms.jpg',
#    'snippet_text': 'At first, I was a bit hesitant about a Segway tour. My wife and I have visited Santa Cruz many times and I was dubious about visiting a place I already knew...',
#    'url': 'https://www.yelp.com/biz/segway-santa-cruz-tours-santa-cruz?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-408-286-1000',
#    'id': 'hotel-de-anza-san-jose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pJZtDTZRK54qaitNuWgAMg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['233 W Santa Clara St'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.33441, 'longitude': -121.89511},
#     'country_code': 'US',
#     'display_address': ['233 W Santa Clara St',
#      'Downtown',
#      'San Jose, CA 95113'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Downtown'],
#     'postal_code': '95113',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hotel-de-anza-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hotel De Anza',
#    'phone': '4082861000',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 228,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/bnFACipu1nVBstZgWDiHeQ/ms.jpg',
#    'snippet_text': 'One of the best decisions my husband and I ever made was choosing Hotel De Anza as our wedding venue. We worked with their events manager, Laura Brown, and...',
#    'url': 'https://www.yelp.com/biz/hotel-de-anza-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['DJs', 'djs']],
#    'display_phone': '+1-408-446-5000',
#    'id': 'joel-nelson-productions-san-jose',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PnGHF_dNS51egeUhbeK_CQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1157 Saratoga Ave'],
#     'city': 'San Jose',
#     'coordinate': {'latitude': 37.30393, 'longitude': -121.97977},
#     'country_code': 'US',
#     'display_address': ['1157 Saratoga Ave',
#      'West San Jose',
#      'San Jose, CA 95129'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['West San Jose'],
#     'postal_code': '95129',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472553525,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/joel-nelson-productions-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Joel Nelson Productions',
#    'phone': '4084465000',
#    'rating': 5.0,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/f1def11e4e79/ico/stars/v1/stars_5.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/22affc4e6c38/ico/stars/v1/stars_large_5.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/c7623205d5cd/ico/stars/v1/stars_small_5.png',
#    'review_count': 57,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/assets/srv0/yelp_styleguide/bf5ff8a79310/assets/img/default_avatars/user_medium_square.png',
#    'snippet_text': "I hired JNP for my daughter's Cotillion last August 2016. \nJoel is easy to work with. \nDJ Vader is awesome and has passion for music! He played all the...",
#    'url': 'https://www.yelp.com/biz/joel-nelson-productions-san-jose?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Parks', 'parks']],
#    'display_phone': '+1-650-691-1200',
#    'id': 'rancho-san-antonio-open-space-preserve-los-altos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v_bzlAyGmX4UW2R-I1CWpQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['22500 Cristo Rey Dr'],
#     'city': 'Los Altos',
#     'coordinate': {'latitude': 37.331257672506, 'longitude': -122.08329126012},
#     'country_code': 'US',
#     'display_address': ['22500 Cristo Rey Dr', 'Los Altos, CA 94024'],
#     'geo_accuracy': 9.5,
#     'postal_code': '94024',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/rancho-san-antonio-open-space-preserve-los-altos?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Rancho San Antonio Open Space Preserve',
#    'phone': '6506911200',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 574,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/Fj3cLnIkCdl3UelmB0ksfA/ms.jpg',
#    'snippet_text': 'This is the perfect place for an early morning workout hikes or last minute hiking plans... \n\nThe view here is amazing and all the nice animals and birds...',
#    'url': 'https://www.yelp.com/biz/rancho-san-antonio-open-space-preserve-los-altos?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'}],
#  'region': {'center': {'latitude': 37.1948410938806,
#    'longitude': -121.9324600070495},
#   'span': {'latitude_delta': 0.5055115865373239,
#    'longitude_delta': 0.3592551755089062}},
#  'total': 1036}

# %%
data=[]
lst[0]
# Out:
# ['yellow', 'orange', 'red']

# %%
lst = [['yellow', 'orange', 'red'],['purple']]
word = "or"
lstt=[]
for i in range(len(lst)):
    for j in lst[i]:
        lstt.append(j)
# Out:
# ['yellow', 'orange', 'red', 'purple']

# %%
if any("r" in s for s in lstt):
    print('True')
# Out:
# True

# %%
v[0]
# Out:
# {'businesses': [{'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-392-9466',
#    'id': 'axiom-hotel-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/voLmATEn7MErqeg0ZsX-bA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['28 Cyril Magnin St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7843596, 'longitude': -122.4082839},
#     'country_code': 'US',
#     'display_address': ['28 Cyril Magnin St',
#      'Union Square',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/axiom-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Axiom Hotel',
#    'phone': '4153929466',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 65,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/yaMAk0xJ9aO-tUWjUGGuhg/ms.jpg',
#    'snippet_text': "This is one of the better no-fuss but really good little hotels, in a knockout location. Although it's right opposite the Powell St cable car terminating...",
#    'url': 'https://www.yelp.com/biz/axiom-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels'], ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-415-788-1234',
#    'id': 'hyatt-regency-san-francisco-san-francisco-2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CLQM3ovY0UalHhkmTnkSrw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['5 Embarcadero Ctr'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7942537009417,
#      'longitude': -122.395849227905},
#     'country_code': 'US',
#     'display_address': ['5 Embarcadero Ctr',
#      'Financial District',
#      'San Francisco, CA 94111'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Financial District'],
#     'postal_code': '94111',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472590587,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/hyatt-regency-san-francisco-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hyatt Regency San Francisco',
#    'phone': '4157881234',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 715,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/JIiDy5eHh6YuTGiN84kZnA/ms.jpg',
#    'snippet_text': 'I enjoyed my stay here at the Hyatt.  The proximity to the Embarcadero makes it super convenient.  You are within walk distance to great restaurants and...',
#    'url': 'https://www.yelp.com/biz/hyatt-regency-san-francisco-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-673-0242',
#    'id': 'hotel-carlton-san-francisco-3',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9HReqHCURGgNbxMoVTRFtw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1075 Sutter Street'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7877036, 'longitude': -122.4181618},
#     'country_code': 'US',
#     'cross_streets': 'Larkin St',
#     'display_address': ['1075 Sutter Street',
#      'Lower Nob Hill',
#      'San Francisco, CA 94109'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Lower Nob Hill'],
#     'postal_code': '94109',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hotel-carlton-san-francisco-3?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hotel Carlton',
#    'phone': '4156730242',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 393,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/Qcl2YezxfXheHmR_CuWKHQ/ms.jpg',
#    'snippet_text': 'Great Union Square location with spacious rooms and comfy beds.\nVery funny front desk guy!!!',
#    'url': 'https://www.yelp.com/biz/hotel-carlton-san-francisco-3?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-633-3000',
#    'id': 'four-seasons-hotel-san-francisco-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kjoErHLIF3sqoXVM6o21kg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['757 Market St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7863857630215,
#      'longitude': -122.404476803829},
#     'country_code': 'US',
#     'cross_streets': 'Ofarrell St & Grant Ave',
#     'display_address': ['757 Market St',
#      'Union Square',
#      'San Francisco, CA 94103'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Union Square', 'Financial District', 'SoMa'],
#     'postal_code': '94103',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472589835,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/four-seasons-hotel-san-francisco-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Four Seasons Hotel San Francisco',
#    'phone': '4156333000',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 266,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/bsyqns47Wl8XnJr-7_SIBg/ms.jpg',
#    'snippet_text': 'What a beautiful hotel! We were here for a company conference and their event place is classy and beautiful. The food there is excellent and service is top...',
#    'url': 'https://www.yelp.com/biz/four-seasons-hotel-san-francisco-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-772-5000',
#    'id': 'fairmont-san-francisco-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3SKbNWx1uYXRJZOYzP7Hrw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['950 Mason St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7924352804106,
#      'longitude': -122.410663910663},
#     'country_code': 'US',
#     'cross_streets': 'Sacramento St & California St',
#     'display_address': ['950 Mason St', 'Nob Hill', 'San Francisco, CA 94108'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Nob Hill'],
#     'postal_code': '94108',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472583938,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/fairmont-san-francisco-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Fairmont San Francisco',
#    'phone': '4157725000',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 783,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/AmxodpjAm9TLahqlWj0hAg/ms.jpg',
#    'snippet_text': 'Very nice hotel. We stayed here for our 3 days trip to San Francisco. The lobby is sooo gorgeous. Love it. Our room is small though. For the price they...',
#    'url': 'https://www.yelp.com/biz/fairmont-san-francisco-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-362-8878',
#    'id': 'the-orchard-hotel-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dHeXxwGwasziyRXmGbQaag/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['665 Bush St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.790064, 'longitude': -122.408398},
#     'country_code': 'US',
#     'cross_streets': 'Chelsea Pl & Powell St',
#     'display_address': ['665 Bush St',
#      'Union Square',
#      'San Francisco, CA 94108'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94108',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472032366,
#    'menu_provider': 'yelp',
#    'mobile_url': 'https://m.yelp.com/biz/the-orchard-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'The Orchard Hotel',
#    'phone': '4153628878',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 128,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/assets/srv0/yelp_styleguide/bf5ff8a79310/assets/img/default_avatars/user_medium_square.png',
#    'snippet_text': 'This is an excellent hotel in a great location, just a couple of blocks from Union Square. The staff was exceptional; from the doorman to the housekeeping...',
#    'url': 'https://www.yelp.com/biz/the-orchard-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-774-0124',
#    'id': 'the-westin-st-francis-san-francisco-on-union-square-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VB8KYJgouIlzedH7Qxmb0Q/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['335 Powell St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7876021, 'longitude': -122.4084259},
#     'country_code': 'US',
#     'cross_streets': 'Post St & Geary St',
#     'display_address': ['335 Powell St',
#      'Union Square',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472583778,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/the-westin-st-francis-san-francisco-on-union-square-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'The Westin St. Francis San Francisco on Union Square',
#    'phone': '4157740124',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 1105,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/tp00pPuuUakwqzrbBn050A/ms.jpg',
#    'snippet_text': 'I fell in love with this hotel...When you walk into this hotel, you can really feel the history and wealth of this place, that old money feeling...I love...',
#    'url': 'https://www.yelp.com/biz/the-westin-st-francis-san-francisco-on-union-square-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-394-1111',
#    'id': 'hotel-nikko-san-francisco-san-francisco-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xRfoLpWSvX-UjMVRua860w/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['222 Mason St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7859844832523,
#      'longitude': -122.409244244422},
#     'country_code': 'US',
#     'cross_streets': 'Ofarrell St & Ellis St',
#     'display_address': ['222 Mason St',
#      'Union Square',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hotel-nikko-san-francisco-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hotel Nikko San Francisco',
#    'phone': '4153941111',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 667,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/BtqTiAvwUjCWGHyIqltWoA/ms.jpg',
#    'snippet_text': 'A beautiful hotel!\n\nOn my most recent trip back home, I booked this hotel for the weekend and found a great deal through Hotels.com\n\nWe had a two queen room...',
#    'url': 'https://www.yelp.com/biz/hotel-nikko-san-francisco-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels'], ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-415-398-1234',
#    'id': 'grand-hyatt-san-francisco-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nS51gDLDZ_ssg-FIG-ORug/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['345 Stockton St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7887472977753,
#      'longitude': -122.407129131949},
#     'country_code': 'US',
#     'cross_streets': 'Sutter St & Stockton St',
#     'display_address': ['345 Stockton St',
#      'Union Square',
#      'San Francisco, CA 94108'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94108',
#     'state_code': 'CA'},
#    'menu_date_updated': 1473014006,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/grand-hyatt-san-francisco-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Grand Hyatt San Francisco',
#    'phone': '4153981234',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 545,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/kDEW77CXOBC-m1NGmXLn3A/ms.jpg',
#    'snippet_text': 'Stayed here for a couple nights for a big work conference, and the location was spot on - right in Union Square, walking distance to Michelin star...',
#    'url': 'https://www.yelp.com/biz/grand-hyatt-san-francisco-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-433-4434',
#    'id': 'hotel-rex-san-francisco-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NF9cb7lnHdBwQgGIaKSf_g/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['562 Sutter St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.789161, 'longitude': -122.409767},
#     'country_code': 'US',
#     'cross_streets': 'Mason St & Powell St',
#     'display_address': ['562 Sutter St',
#      'Union Square',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hotel-rex-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hotel Rex',
#    'phone': '4154334434',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 190,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/L1XleZ4oRNjH4bfXvQyRVg/ms.jpg',
#    'snippet_text': 'Thoroughly impressed. This whole place is adorable, gorgeously decorated & cozy. Plus not only do I have 1 &1/2 bathrooms in my suite, they offer tooth...',
#    'url': 'https://www.yelp.com/biz/hotel-rex-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-896-1600',
#    'id': 'san-francisco-marriott-marquis-san-francisco-2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VpSVQCbX7C78ZqwR6o3Fmg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['780 Mission Street'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7848977064112,
#      'longitude': -122.403850745866},
#     'country_code': 'US',
#     'cross_streets': 'Opera Aly & 4th St',
#     'display_address': ['780 Mission Street',
#      'Financial District',
#      'San Francisco, CA 94103'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Financial District', 'SoMa'],
#     'postal_code': '94103',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/san-francisco-marriott-marquis-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'San Francisco Marriott Marquis',
#    'phone': '4158961600',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 696,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/fKKo9o2sUN6LmE9Nxu9OtQ/ms.jpg',
#    'snippet_text': 'Great location. Near the Bart and Cable cars. Numerous restaurants and shopping mall near by.\nRoom was spacious. Plenty of towels provided .\nI would stay...',
#    'url': 'https://www.yelp.com/biz/san-francisco-marriott-marquis-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-928-6000',
#    'id': 'petite-auberge-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_eO4GtaDoyXbiGeJr_6UCQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['863 Bush St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78969, 'longitude': -122.41143},
#     'country_code': 'US',
#     'cross_streets': 'Taylor St & Mason St',
#     'display_address': ['863 Bush St',
#      'Union Square',
#      'San Francisco, CA 94108'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Union Square', 'Lower Nob Hill'],
#     'postal_code': '94108',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/petite-auberge-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Petite Auberge',
#    'phone': '4159286000',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 67,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/zFd3gVm53s-b-JtWFBHNAw/ms.jpg',
#    'snippet_text': 'The loveliest BnB in San Fran! I stayed here for about 3 days 2 nights after graduating college, and loved how accessible it was. It was right in the middle...',
#    'url': 'https://www.yelp.com/biz/petite-auberge-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-931-7475',
#    'id': 'dakota-hotel-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uBtBjEVkr4OFAnDvT0kwMQ/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['606 Post St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78795, 'longitude': -122.41194},
#     'country_code': 'US',
#     'cross_streets': 'Taylor St & Trader Vic Aly',
#     'display_address': ['606 Post St',
#      'Lower Nob Hill',
#      'San Francisco, CA 94109'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Lower Nob Hill'],
#     'postal_code': '94109',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/dakota-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Dakota Hotel',
#    'phone': '4159317475',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 33,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/6DhciVtyhVUyp45jRHPLhA/ms.jpg',
#    'snippet_text': 'LOVED this place! Very cool vibe because the building is old...the elevator is over 100 years old! We had a room on the 8th floor with a beautiful view of...',
#    'url': 'https://www.yelp.com/biz/dakota-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-362-2004',
#    'id': 'chancellor-hotel-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5CTPBkaHMkvReEZn_MIPkw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['433 Powell St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78866, 'longitude': -122.40861},
#     'country_code': 'US',
#     'cross_streets': 'Post St & Sutter St',
#     'display_address': ['433 Powell St',
#      'Union Square',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/chancellor-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Chancellor Hotel',
#    'phone': '4153622004',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 214,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/rlF814lNQhrWe7Ttmyb5RA/ms.jpg',
#    'snippet_text': "Alicia the bartender on Wednesday night is awesome! She was super friendly and extremely knowledgeable of the city! I've lived in Oakland for over 20 years...",
#    'url': 'https://www.yelp.com/biz/chancellor-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-775-3800',
#    'id': 'courtyard-san-francisco-fishermans-wharf-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8KJarGPIa-AeLumED9FRVQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['580 Beach St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.8071447927878,
#      'longitude': -122.418313660655},
#     'country_code': 'US',
#     'cross_streets': 'Jones St & Leavenworth St',
#     'display_address': ['580 Beach St',
#      'North Beach/Telegraph Hill',
#      'San Francisco, CA 94133'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['North Beach/Telegraph Hill', "Fisherman's Wharf"],
#     'postal_code': '94133',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/courtyard-san-francisco-fishermans-wharf-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "Courtyard San Francisco Fisherman's Wharf",
#    'phone': '4157753800',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 98,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/dyhiBS6u5sSCKsIV1UTK-A/ms.jpg',
#    'snippet_text': "The staff here made our trip so enjoyable and the reason why I'm giving this hotel 5 stars.  \n\nBrandon at the front desk is a delightful 21-year old with a...",
#    'url': 'https://www.yelp.com/biz/courtyard-san-francisco-fishermans-wharf-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-399-9807',
#    'id': 'orchard-garden-hotel-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1h3asLunQCZ_7EW52PGDOA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['466 Bush St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.790869, 'longitude': -122.405226},
#     'country_code': 'US',
#     'cross_streets': 'Grant Ave',
#     'display_address': ['466 Bush St', 'Chinatown', 'San Francisco, CA 94108'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Chinatown'],
#     'postal_code': '94108',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/orchard-garden-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'The Orchard Garden Hotel',
#    'phone': '4153999807',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 145,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/assets/srv0/yelp_styleguide/bf5ff8a79310/assets/img/default_avatars/user_medium_square.png',
#    'snippet_text': 'We really enjoyed our stay at Orchard Garden. The staff was wonderful - friendly and helpful. This was our first trip to San Francisco and they provided...',
#    'url': 'https://www.yelp.com/biz/orchard-garden-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-617-6565',
#    'id': 'hotel-zephyr-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qJ7goR19YR13p2cUF56_Jg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['250 Beach St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.8084544058206,
#      'longitude': -122.41315400811},
#     'country_code': 'US',
#     'cross_streets': 'Powell St & Mason St',
#     'display_address': ['250 Beach St',
#      'North Beach/Telegraph Hill',
#      'San Francisco, CA 94133'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['North Beach/Telegraph Hill', "Fisherman's Wharf"],
#     'postal_code': '94133',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hotel-zephyr-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hotel Zephyr',
#    'phone': '4156176565',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 152,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Lc_p5K0zdDg1NF8oDQmdug/ms.jpg',
#    'snippet_text': 'I used the Yelp special rate to get a discount at this hotel, we stayed for one night on 9/24 and had a wonderful time.\n\nThe front desk was able to hold our...',
#    'url': 'https://www.yelp.com/biz/hotel-zephyr-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-921-9406',
#    'id': 'marina-motel-san-francisco-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p9bYjABJzeYgvUXgUukzzQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2576 Lombard Street'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7991699, 'longitude': -122.44388},
#     'country_code': 'US',
#     'cross_streets': 'Divisadero St & United States Highway 101',
#     'display_address': ['2576 Lombard Street',
#      'Marina/Cow Hollow',
#      'San Francisco, CA 94123'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Marina/Cow Hollow'],
#     'postal_code': '94123',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/marina-motel-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Marina Motel',
#    'phone': '4159219406',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 98,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/g1G_ouvBBl5cCnGKgpqjnA/ms.jpg',
#    'snippet_text': 'Guys, you need to stop here if you plan on visiting San Fransisco. This place is amazing, the shindig, the place where you are literally minutes away from...',
#    'url': 'https://www.yelp.com/biz/marina-motel-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-398-8900',
#    'id': 'san-francisco-marriott-union-square-san-francisco-3',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z7K8X2b1gjt1KwmZlFpv5A/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['480 Sutter Street'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78954, 'longitude': -122.4083},
#     'country_code': 'US',
#     'cross_streets': 'Powell St',
#     'display_address': ['480 Sutter Street',
#      'Union Square',
#      'San Francisco, CA 94108'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94108',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/san-francisco-marriott-union-square-san-francisco-3?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'San Francisco Marriott Union Square',
#    'phone': '4153988900',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 215,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/yZuR3SU0qAhXYXnoSD-tgQ/ms.jpg',
#    'snippet_text': 'This Marriott should not be confused with the "Jukebox Marriott" near the Moscone Center or the nearby JW Marriott. I made that mistake regarding the...',
#    'url': 'https://www.yelp.com/biz/san-francisco-marriott-union-square-san-francisco-3?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-552-7100',
#    'id': 'casa-loma-hotel-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JlZf6bFGkDh5PmwZLKoRnA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['610 Fillmore St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.77508, 'longitude': -122.43085},
#     'country_code': 'US',
#     'cross_streets': 'Fell St & Hayes St',
#     'display_address': ['610 Fillmore St',
#      'Hayes Valley',
#      'San Francisco, CA 94117'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Hayes Valley', 'Alamo Square'],
#     'postal_code': '94117',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/casa-loma-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Casa Loma Hotel',
#    'phone': '4155527100',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 115,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/JxAofYO6yELzHv49krsI-A/ms.jpg',
#    'snippet_text': "I stayed here because this was the only hotel that was available last minute. I opted for one of their larger rooms but it didn't have a private...",
#    'url': 'https://www.yelp.com/biz/casa-loma-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels'], ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-415-921-4000',
#    'id': 'kimpton-buchanan-hotel-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BmVTzaAFIkNmzq2t3FtXmA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1800 Sutter St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78679, 'longitude': -122.43032},
#     'country_code': 'US',
#     'cross_streets': 'Webster St & Buchanan St',
#     'display_address': ['1800 Sutter St',
#      'Japantown',
#      'San Francisco, CA 94115'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Japantown', 'Lower Pacific Heights'],
#     'postal_code': '94115',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/kimpton-buchanan-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Kimpton Buchanan Hotel',
#    'phone': '4159214000',
#    'rating': 3.0,
#    'rating_img_url': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/34bc8086841c/ico/stars/v1/stars_3.png',
#    'rating_img_url_large': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/e8b5b79d37ed/ico/stars/v1/stars_large_3.png',
#    'rating_img_url_small': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/902abeed0983/ico/stars/v1/stars_small_3.png',
#    'review_count': 65,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/hd2NypkGeHrjDe6AM9YG2w/ms.jpg',
#    'snippet_text': 'Japantown in San Francisco is one of the more interesting and convenient places to stay. It was always one of my favorite places to chill and hang around....',
#    'url': 'https://www.yelp.com/biz/kimpton-buchanan-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-397-0657',
#    'id': 'bay-bridge-inn-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kep4V48-9EJOJMhKOnr7sA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['966 Harrison St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.77811, 'longitude': -122.40359},
#     'country_code': 'US',
#     'cross_streets': 'Merlin St & 5th St',
#     'display_address': ['966 Harrison St', 'SoMa', 'San Francisco, CA 94107'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['SoMa'],
#     'postal_code': '94107',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/bay-bridge-inn-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Bay Bridge Inn',
#    'phone': '4153970657',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 98,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/FnTJxPHoUlWSu0uEcmO3Lw/ms.jpg',
#    'snippet_text': 'Stayed here for one night on August 8, 2016! It was pretty nice and the owner was very sweet.\n\nIt was my first time staying in downtown sf and I was very...',
#    'url': 'https://www.yelp.com/biz/bay-bridge-inn-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-775-5000',
#    'id': 'hotel-adagio-autograph-collection-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yzOp07Tinr7Dgd2M1t6tew/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['550 Geary St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7869650797446,
#      'longitude': -122.412525531823},
#     'country_code': 'US',
#     'cross_streets': 'Jones St & Shannon St',
#     'display_address': ['550 Geary St',
#      'Lower Nob Hill',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Lower Nob Hill'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hotel-adagio-autograph-collection-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hotel Adagio, Autograph Collection',
#    'phone': '4157755000',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 327,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/Pg5W8jypUIaKllB2Qs6KNQ/ms.jpg',
#    'snippet_text': "We've stayed at Diva's and the Clift which are like a block away.  Both are ok but with so many choices we decided to try the Adagio - which is a Marriott...",
#    'url': 'https://www.yelp.com/biz/hotel-adagio-autograph-collection-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-752-8000',
#    'id': 'seal-rock-inn-san-francisco-2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jYa2OrT6ZfPR-AZfLnSVQw/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['545 Point Lobos Ave'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.77964, 'longitude': -122.50912},
#     'country_code': 'US',
#     'cross_streets': '48th Ave & 47th Ave',
#     'display_address': ['545 Point Lobos Ave',
#      'Outer Richmond',
#      'San Francisco, CA 94121'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Outer Richmond'],
#     'postal_code': '94121',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/seal-rock-inn-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Seal Rock Inn',
#    'phone': '4157528000',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 259,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/FIZ6DX1E3a337jS8g-1i7Q/ms.jpg',
#    'snippet_text': 'We so want to come back and spend a week! And, as prior SF residents (15 years for your author) I think that speaks for itself. \n\nMy wife and I stayed at...',
#    'url': 'https://www.yelp.com/biz/seal-rock-inn-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-512-1111',
#    'id': 'palace-hotel-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/blBixuBJwtLBHBMJks604Q/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2 New Montgomery St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7882573288363,
#      'longitude': -122.401706778141},
#     'country_code': 'US',
#     'cross_streets': 'Stevenson St & Market St',
#     'display_address': ['2 New Montgomery St',
#      'Financial District',
#      'San Francisco, CA 94105'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Financial District', 'SoMa'],
#     'postal_code': '94105',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/palace-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Palace Hotel',
#    'phone': '4155121111',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 844,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/fGA_wHXOmNaJeY2N0QUXCQ/ms.jpg',
#    'snippet_text': 'Fantastic Hotel.  I love staying here.  The room is comfortable and quiet.  The amenities are first-rate but what puts this hotel over the top are the...',
#    'url': 'https://www.yelp.com/biz/palace-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels'], ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-415-213-2746',
#    'id': 'payne-mansion-hotel-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qCgoRmRWrVdvLsRrjCGlPw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1409 Sutter St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7871499, 'longitude': -122.42385},
#     'country_code': 'US',
#     'cross_streets': 'Gough St & Franklin St',
#     'display_address': ['1409 Sutter St',
#      'Lower Pacific Heights',
#      'San Francisco, CA 94109'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Lower Pacific Heights'],
#     'postal_code': '94109',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/payne-mansion-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Payne Mansion Hotel',
#    'phone': '4152132746',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
# ...
#    'review_count': 356,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/8m_hWncM1trSEQdFko-TMQ/ms.jpg',
#    'snippet_text': 'My wife and I were having a wee weekend in San Francisco together and ended up staying at the Serrano Hotel.\n\nThe good points - insanely easy to get to...',
#    'url': 'https://www.yelp.com/biz/serrano-hotel-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-885-1492',
#    'id': 'columbus-motor-inn-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WnPeerP1ONg8Ags0EtahUQ/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['1075 Columbus Ave'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.80406, 'longitude': -122.41586},
#     'country_code': 'US',
#     'cross_streets': 'Houston St & Francisco St',
#     'display_address': ['1075 Columbus Ave',
#      'Russian Hill',
#      'San Francisco, CA 94133'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Russian Hill'],
#     'postal_code': '94133',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/columbus-motor-inn-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Columbus Motor Inn',
#    'phone': '4158851492',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 86,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/Qka1TUCKlpbqKBSlmsU94Q/ms.jpg',
#    'snippet_text': 'Staying at the Columbus Motor Inn was one of the best decisions we made when picking a place to stay in San Francisco.  \n\nSome of my favorite features...',
#    'url': 'https://www.yelp.com/biz/columbus-motor-inn-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-392-8000',
#    'id': 'parc-55-san-francisco-a-hilton-hotel-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7n4UB1Ufa5Ok93UC_v18ag/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['55 Cyril Magnin St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78487, 'longitude': -122.40896},
#     'country_code': 'US',
#     'cross_streets': 'Hallidie Plz & Eddy St',
#     'display_address': ['55 Cyril Magnin St',
#      'Union Square',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472598498,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/parc-55-san-francisco-a-hilton-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Parc 55 San Francisco - A Hilton Hotel',
#    'phone': '4153928000',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 1013,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/88F5pIdHbAQty5UPYygWbA/ms.jpg',
#    'snippet_text': 'Review #200!\n\nParc 55 was the highlight of my quick Thanksiversary getaway with my gf to SF. Great location, great service, cool hotel from the inside &...',
#    'url': 'https://www.yelp.com/biz/parc-55-san-francisco-a-hilton-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-788-6400',
#    'id': 'kensington-park-hotel-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C--paUL5srfBptK7CLjevQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['450 Post St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78828, 'longitude': -122.4093},
#     'country_code': 'US',
#     'cross_streets': 'Powell St & Mason St',
#     'display_address': ['450 Post St',
#      'Union Square',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Union Square'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/kensington-park-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Kensington Park Hotel',
#    'phone': '4157886400',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 150,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/bx0_EbkP-f8SoJB5tthCIA/ms.jpg',
#    'snippet_text': "As you walk in, you know that there is a lot of history here. Seems pretty old.\n\nWhich is why they didn't have air conditioning. But the fan worked. And no...",
#    'url': 'https://www.yelp.com/biz/kensington-park-hotel-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels'], ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-415-626-6103',
#    'id': 'holiday-inn-san-francisco-civic-center-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M8UXQC7HAxXM53WqWNbUuQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['50 8th St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.77757, 'longitude': -122.41427},
#     'country_code': 'US',
#     'cross_streets': 'Stevenson St & Mission St',
#     'display_address': ['50 8th St', 'SoMa', 'San Francisco, CA 94103'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['SoMa'],
#     'postal_code': '94103',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/holiday-inn-san-francisco-civic-center-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Holiday Inn San Francisco-Civic Center',
#    'phone': '4156266103',
#    'rating': 3.0,
#    'rating_img_url': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/34bc8086841c/ico/stars/v1/stars_3.png',
#    'rating_img_url_large': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/e8b5b79d37ed/ico/stars/v1/stars_large_3.png',
#    'rating_img_url_small': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/902abeed0983/ico/stars/v1/stars_small_3.png',
#    'review_count': 160,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/NSpoUz1jcED531W60XBJVg/ms.jpg',
#    'snippet_text': 'Booked a room here because it was a 5 minute walk from Bill Graham Civic Auditorium where my friends and I were attending an event for the weekend.\n\nI knew...',
#    'url': 'https://www.yelp.com/biz/holiday-inn-san-francisco-civic-center-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-433-6600',
#    'id': 'hilton-san-francisco-financial-district-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lc4oOMS5a3lqUVl0u8uZcg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['750 Kearny St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.79514, 'longitude': -122.40431},
#     'country_code': 'US',
#     'cross_streets': 'Merchant St & Washington St',
#     'display_address': ['750 Kearny St',
#      'Financial District',
#      'San Francisco, CA 94108'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Financial District'],
#     'postal_code': '94108',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472594246,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/hilton-san-francisco-financial-district-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hilton San Francisco Financial District',
#    'phone': '4154336600',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 511,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/BOMft09YuUhav8xhwkJ6JA/ms.jpg',
#    'snippet_text': '25 Years ago I stayed in this same hotel.  I had won tickets to go and see Paul McCartney in Berkley and this was the nearest best hotel that I could afford...',
#    'url': 'https://www.yelp.com/biz/hilton-san-francisco-financial-district-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-921-5800',
#    'id': 'cow-hollow-motor-inn-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Bw0m5Bqe6jva_FtY0wNzaA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2190 Lombard St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7997979, 'longitude': -122.4374321},
#     'country_code': 'US',
#     'cross_streets': 'Fillmore St & Steiner St',
#     'display_address': ['2190 Lombard St',
#      'Marina/Cow Hollow',
#      'San Francisco, CA 94123'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Marina/Cow Hollow'],
#     'postal_code': '94123',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/cow-hollow-motor-inn-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Cow Hollow Motor Inn',
#    'phone': '4159215800',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 130,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/q7BmUEmumRevJVM2ldFedw/ms.jpg',
#    'snippet_text': 'I was very hesitant to book this hotel, simply because it looked like it was on "motel row" but it was the best deal we could find for a late booking to San...',
#    'url': 'https://www.yelp.com/biz/cow-hollow-motor-inn-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-563-0303',
#    'id': 'hotel-zeppelin-san-francisco-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YEd_iyaFggJ3u3xUk6vLLQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['545 Post St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78787, 'longitude': -122.41073},
#     'country_code': 'US',
#     'cross_streets': 'Taylor St & Mason St',
#     'display_address': ['545 Post St',
#      'Union Square',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Union Square', 'Lower Nob Hill'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/hotel-zeppelin-san-francisco-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Hotel Zeppelin San Francisco',
#    'phone': '4155630303',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 54,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/Mw9xF5Jjxv8VqeB5827zxg/ms.jpg',
#    'snippet_text': 'This review comes after a very special trip to Hotel Zeppelin because of the kindness of the truly special staff of this hotel. \n\nYes, this hotel looks...',
#    'url': 'https://www.yelp.com/biz/hotel-zeppelin-san-francisco-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hotels', 'hotels']],
#    'display_phone': '+1-415-885-4700',
#    'id': 'pier-2620-hotel-fishermans-wharf-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VmTSBGei1_RxM4BS2G1EnQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2620 Jones St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.8053317219019,
#      'longitude': -122.416863664985},
#     'country_code': 'US',
#     'cross_streets': 'North Point St & Bay St',
#     'display_address': ['2620 Jones St',
#      'Russian Hill',
#      'San Francisco, CA 94133'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Russian Hill',
#      'North Beach/Telegraph Hill',
#      "Fisherman's Wharf"],
#     'postal_code': '94133',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/pier-2620-hotel-fishermans-wharf-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "Pier 2620 Hotel Fisherman's Wharf",
#    'phone': '4158854700',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 181,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/ceLYbF8j_dg7W4UrEYZftw/ms.jpg',
#    'snippet_text': 'I really enjoyed this hotel - excellent service and solid rooms with unique decor.\n\nThe location is also excellent.\n\nPro-tip:  If you have a car there is a...',
#    'url': 'https://www.yelp.com/biz/pier-2620-hotel-fishermans-wharf-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'}],
#  'region': {'center': {'latitude': 37.7917711529103,
#    'longitude': -122.4525039639525},
#   'span': {'latitude_delta': 0.03670315640265187,
#    'longitude_delta': 0.12464041930448388}},
#  'total': 3855}

# %%
data=[]

# %%
for i in range(len(v)):
    for j in range(len(v[i]['businesses'])):
           data.append(v[i]['businesses'][j])

# %%
data[50]
# Out:
# {'categories': [['Landmarks & Historical Buildings', 'landmarks']],
#  'display_phone': '+1-415-556-1693',
#  'id': 'fort-point-san-francisco',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SocN3OK6QEh4T76XqmLbUw/ms.jpg',
#  'is_claimed': False,
#  'is_closed': False,
#  'location': {'address': ['Marine Dr'],
#   'city': 'San Francisco',
#   'coordinate': {'latitude': 37.8103264355348, 'longitude': -122.476830482483},
#   'country_code': 'US',
#   'display_address': ['Marine Dr', 'Presidio', 'San Francisco, CA 94123'],
#   'geo_accuracy': 9.5,
#   'neighborhoods': ['Presidio'],
#   'postal_code': '94123',
#   'state_code': 'CA'},
#  'mobile_url': 'https://m.yelp.com/biz/fort-point-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#  'name': 'Fort Point',
#  'phone': '4155561693',
#  'rating': 5.0,
#  'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/f1def11e4e79/ico/stars/v1/stars_5.png',
#  'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/22affc4e6c38/ico/stars/v1/stars_large_5.png',
#  'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/c7623205d5cd/ico/stars/v1/stars_small_5.png',
#  'review_count': 303,
#  'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/Nil386VshKE5gsi0Eg6iUg/ms.jpg',
#  'snippet_text': 'Hidden gem! Perfect place to get a picture with the Golden Gate Bridge in the background. \n\nNeat fort to explore as well. Parking seemed to be easy. A...',
#  'url': 'https://www.yelp.com/biz/fort-point-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'}

# %%
kk = list(set(i.lower() for i in v[9]['businesses'][0]['categories'][0] ))
kk
# Out:
# ['korean']

# %%
#requests.get('https://api.yelp.com/v2/business/kadampa-meditation-center-san-francisco-san-francisco',auth=uauth,headers=headers).json()

# %%
v[0]
# Out:
# {'businesses': [{'categories': [['Burmese', 'burmese'],
#     ['Cocktail Bars', 'cocktailbars'],
#     ['Salad', 'salad']],
#    'display_phone': '+1-415-861-2100',
#    'id': 'burma-love-san-francisco-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ofu7k8bW9GxG_kBlcTF30w/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['211 Valencia St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.76961, 'longitude': -122.42205},
#     'country_code': 'US',
#     'cross_streets': 'Duboce Ave & Clinton Park',
#     'display_address': ['211 Valencia St',
#      'Mission',
#      'San Francisco, CA 94103'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Mission'],
#     'postal_code': '94103',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472682299,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/burma-love-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Burma Love',
#    'phone': '4158612100',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 509,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/Lz4zbmyPQfVtD1EUPbDLHQ/ms.jpg',
#    'snippet_text': 'Mint Chicken 4/5\nCalamari 5/5 + the unexpected winner here\nRainbow Salad 5/5\nPinot Noir (on tap) 4/5\n\nGreat evening at Burma Love - we waited for about 45...',
#    'url': 'https://www.yelp.com/biz/burma-love-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Greek', 'greek'],
#     ['Turkish', 'turkish'],
#     ['Mediterranean', 'mediterranean']],
#    'display_phone': '+1-415-753-9479',
#    'id': 'kitchen-istanbul-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GCPDzryQgDMYBWgLQjbGsg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['349 Clement St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7828843958139,
#      'longitude': -122.463225816122},
#     'country_code': 'US',
#     'cross_streets': '5th Ave & 4th Ave',
#     'display_address': ['349 Clement St',
#      'Inner Richmond',
#      'San Francisco, CA 94118'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Inner Richmond'],
#     'postal_code': '94118',
#     'state_code': 'CA'},
#    'menu_date_updated': 1479278471,
#    'menu_provider': 'yelp',
#    'mobile_url': 'https://m.yelp.com/biz/kitchen-istanbul-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Kitchen Istanbul',
#    'phone': '4157539479',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 269,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/aaAwjaBNw1F8kWSM_uIqxg/ms.jpg',
#    'snippet_text': "I've come here for brunch few times, and it was delicious each time. The fruit and yoghurt is so good. Falafels are crisp and come a with a yoghurt based...",
#    'url': 'https://www.yelp.com/biz/kitchen-istanbul-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Coffee & Tea', 'coffee'],
#     ['Breakfast & Brunch', 'breakfast_brunch']],
#    'id': 'farm-table-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ynBEtSjPPcs50UBCo28AGQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['754 Post St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7876476643898,
#      'longitude': -122.414076908221},
#     'country_code': 'US',
#     'cross_streets': 'Jones St & Leavenworth St',
#     'display_address': ['754 Post St',
#      'Lower Nob Hill',
#      'San Francisco, CA 94109'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Lower Nob Hill'],
#     'postal_code': '94109',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472634903,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/farm-table-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'farm : table',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 1225,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/gQtXSQciuKoJD7xvAwtolA/ms.jpg',
#    'snippet_text': "This hidden gem and hole-in-the-wall hipster brunch spot is located a couple blocks west of Union Square. While it isn't big with only a communal table...",
#    'url': 'https://www.yelp.com/biz/farm-table-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Mexican', 'mexican']],
#    'display_phone': '+1-415-742-5505',
#    'id': 'padrecito-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gS6KFC5flYmipGa4SnD1fg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['901 Cole St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7656775, 'longitude': -122.4500746},
#     'country_code': 'US',
#     'cross_streets': 'Parnassus Ave & Carl St',
#     'display_address': ['901 Cole St',
#      'Cole Valley',
#      'San Francisco, CA 94117'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Cole Valley'],
#     'postal_code': '94117',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472779956,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/padrecito-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Padrecito',
#    'phone': '4157425505',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 586,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/WBqb3hwApOJEcTqOxFAKSQ/ms.jpg',
#    'snippet_text': "Food, ambiance, bar/cocktails, and service are always consistently great. I've never had a bad meal here, and I don't know anyone else that has either. It's...",
#    'url': 'https://www.yelp.com/biz/padrecito-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['American (New)', 'newamerican']],
#    'display_phone': '+1-415-814-3709',
#    'id': '3rd-cousin-san-francisco-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/t6H-McWbDz35vVQvwiI7Vw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['919 Cortland Ave'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.739031375583,
#      'longitude': -122.413579758197},
#     'country_code': 'US',
#     'cross_streets': 'Folsom St & Gates St',
#     'display_address': ['919 Cortland Ave',
#      'Bernal Heights',
#      'San Francisco, CA 94110'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Bernal Heights'],
#     'postal_code': '94110',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472869267,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/3rd-cousin-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': '3rd Cousin',
#    'phone': '4158143709',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 73,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/1mArbVvEzZ1x7gH1Kp3YrQ/ms.jpg',
#    'snippet_text': 'We got the tasting and menu and let me tell you, so worth it! No only were all the dishes mouthwatering with great flavor balance but the amount you get for...',
#    'url': 'https://www.yelp.com/biz/3rd-cousin-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Mexican', 'mexican']],
#    'display_phone': '+1-415-824-7877',
#    'id': 'el-farolito-san-francisco-2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c0rjUSiz2WyaAURKOTEvww/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2779 Mission St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.752654, 'longitude': -122.4181915},
#     'country_code': 'US',
#     'cross_streets': '24th St & 23rd St',
#     'display_address': ['2779 Mission St',
#      'Mission',
#      'San Francisco, CA 94110'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Mission'],
#     'postal_code': '94110',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472584084,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/el-farolito-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'El Farolito',
#    'phone': '4158247877',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 4019,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/W6xJkxY5_RCV3zlW11RonA/ms.jpg',
#    'snippet_text': 'Stopped at EL FAROLITO the other night on the way to the Bill Graham Civic Auditorium. I had only been to the San Jose branch and found it underwhelming to...',
#    'url': 'https://www.yelp.com/biz/el-farolito-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['American (New)', 'newamerican']],
#    'display_phone': '+1-415-374-7479',
#    'id': 'hoffmanns-grill-and-rotisserie-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PTgoDWykx5yC42JzNSAUdQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1000 Guerrero St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7549706, 'longitude': -122.4235001},
#     'country_code': 'US',
#     'cross_streets': 'Alvarado St & 22nd St',
#     'display_address': ['1000 Guerrero St',
#      'Mission',
#      'San Francisco, CA 94110'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Mission'],
#     'postal_code': '94110',
#     'state_code': 'CA'},
#    'menu_date_updated': 1479891989,
#    'menu_provider': 'eat24',
#    'mobile_url': 'https://m.yelp.com/biz/hoffmanns-grill-and-rotisserie-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "Hoffmann's Grill & Rotisserie",
#    'phone': '4153747479',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 136,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/sRjsTSuBFBVxVw1WbtnYjQ/ms.jpg',
#    'snippet_text': 'Nice comfort food restaurant\n\nCame here early, avoided lines\n\nWonderful bread\n\nShared whole rotisserie chicken served with potatoes and onions, followed by...',
#    'url': 'https://www.yelp.com/biz/hoffmanns-grill-and-rotisserie-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Chinese', 'chinese']],
#    'display_phone': '+1-415-989-8898',
#    'id': 'sam-wo-restaurant-san-francisco-3',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5mOEmllmTcoJ3xpmLrHAmg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['713 Clay St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7942898, 'longitude': -122.4049799},
#     'country_code': 'US',
#     'cross_streets': 'Kearny St & Walter U Lum Pl',
#     'display_address': ['713 Clay St', 'Chinatown', 'San Francisco, CA 94108'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Chinatown'],
#     'postal_code': '94108',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472897456,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/sam-wo-restaurant-san-francisco-3?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Sam Wo Restaurant',
#    'phone': '4159898898',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 305,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/_h4MEjSwtNueZHUFqdTRzA/ms.jpg',
#    'snippet_text': 'We came here a few times last week during our yearly visit to SF. The food and service were both very good. One night we came around 11pm (glad to see they...',
#    'url': 'https://www.yelp.com/biz/sam-wo-restaurant-san-francisco-3?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Cajun/Creole', 'cajun'],
#     ['Southern', 'southern'],
#     ['Soul Food', 'soulfood']],
#    'display_phone': '+1-415-341-1031',
#    'id': 'buttermilk-southern-kitchen-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kqHnH4yi8gRGfReuvTe4AA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2848 23rd St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7544197297833, 'longitude': -122.4092515558},
#     'country_code': 'US',
#     'cross_streets': 'York St & Bryant St',
#     'display_address': ['2848 23rd St', 'Mission', 'San Francisco, CA 94110'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Mission'],
#     'postal_code': '94110',
#     'state_code': 'CA'},
#    'menu_date_updated': 1480515659,
#    'menu_provider': 'eat24',
#    'mobile_url': 'https://m.yelp.com/biz/buttermilk-southern-kitchen-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Buttermilk Southern Kitchen',
#    'phone': '4153411031',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 310,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/JVkrXOVSqWkvzmvRtIQmFA/ms.jpg',
#    'snippet_text': 'EVERYTHING. WAS. AMAZING. OH MY GOD! From the fried chicken to the bbq short rib, my friends and I are convinced this place can do no wrong. Seriously the...',
#    'url': 'https://www.yelp.com/biz/buttermilk-southern-kitchen-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Taiwanese', 'taiwanese']],
#    'display_phone': '+1-415-813-8800',
#    'id': 'the-chairman-san-francisco-2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D8M8ikcWQTyw_NhLIZK7MQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['670 Larkin St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7840223067038,
#      'longitude': -122.41758517921},
#     'country_code': 'US',
#     'cross_streets': 'Willow St & Ellis St',
#     'display_address': ['670 Larkin St',
#      'Tenderloin',
#      'San Francisco, CA 94109'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Tenderloin'],
#     'postal_code': '94109',
#     'state_code': 'CA'},
#    'menu_date_updated': 1479647768,
#    'menu_provider': 'eat24',
#    'mobile_url': 'https://m.yelp.com/biz/the-chairman-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'The Chairman',
#    'phone': '4158138800',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 383,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/iq81WILx0NuaiYBnSkxq7g/ms.jpg',
#    'snippet_text': 'This review is for the Coca Cola braised pork steam bun only, this is my favorite.\n\nFirst time I had chairman bao was at an Off the Grid food truck event at...',
#    'url': 'https://www.yelp.com/biz/the-chairman-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Coffee & Tea', 'coffee'],
#     ['Middle Eastern', 'mideastern'],
#     ['Sandwiches', 'sandwiches']],
#    'display_phone': '+1-415-340-9765',
#    'id': 'ro-cafe-san-francisco-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WoW7RUlvCF0QmNUCh-AUyQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2739 Geary St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7821067602103,
#      'longitude': -122.448417507112},
#     'country_code': 'US',
#     'cross_streets': 'Emerson St & Wood St',
#     'display_address': ['2739 Geary St',
#      'Laurel Heights',
#      'San Francisco, CA 94118'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Laurel Heights', 'Inner Richmond'],
#     'postal_code': '94118',
#     'state_code': 'CA'},
#    'menu_date_updated': 1474013934,
#    'menu_provider': 'eat24',
#    'mobile_url': 'https://m.yelp.com/biz/ro-cafe-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Ro Cafe',
#    'phone': '4153409765',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 54,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/pfscCHs2suGOyhlqTDhCNQ/ms.jpg',
#    'snippet_text': 'Ro Cafe has a potent, tasty selection of Kurdish coffees and a variety of quick easy meal options.\n\nThe staff are friendly and promote a relaxing atmosphere...',
#    'url': 'https://www.yelp.com/biz/ro-cafe-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Cuban', 'cuban'],
#     ['Tapas Bars', 'tapas'],
#     ['Latin American', 'latin']],
#    'display_phone': '+1-415-386-7670',
#    'id': 'cha-cha-cha-san-francisco-4',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5LXiG71SRFsYSPrYwsYkow/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1801 Haight St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7691434, 'longitude': -122.4520399},
#     'country_code': 'US',
#     'cross_streets': 'Shrader St & Stanyan St',
#     'display_address': ['1801 Haight St',
#      'The Haight',
#      'San Francisco, CA 94117'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['The Haight'],
#     'postal_code': '94117',
#     'state_code': 'CA'},
#    'menu_date_updated': 1478257091,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/cha-cha-cha-san-francisco-4?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Cha Cha Cha',
#    'phone': '4153867670',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 2838,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/yf7W5n8MicYjKmCyIn5uUA/ms.jpg',
#    'snippet_text': "After drinking the evening away, I was hungry! Peter L wanted to go to a place I'd never been before, so after yelping places nearby, we decided on Cha Cha...",
#    'url': 'https://www.yelp.com/biz/cha-cha-cha-san-francisco-4?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Mediterranean', 'mediterranean'],
#     ['Tapas/Small Plates', 'tapasmallplates']],
#    'display_phone': '+1-415-957-5463',
#    'id': 'barcha-san-francisco-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/g-hladv-zOwsea6_m3GyFw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['28 Fremont St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7909007, 'longitude': -122.3975146},
#     'country_code': 'US',
#     'cross_streets': 'Front St & Mission St',
#     'display_address': ['28 Fremont St',
#      'Financial District',
#      'San Francisco, CA 94105'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Financial District', 'SoMa'],
#     'postal_code': '94105',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472897713,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/barcha-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Barcha',
#    'phone': '4159575463',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 129,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/J-zbhKy1MLJDWaZBiXAPrw/ms.jpg',
#    'snippet_text': 'This place is awesome for a workday sit down lunch but because there are so few options in the area there is a little bit of a crutch at lunchtime. Luckily...',
#    'url': 'https://www.yelp.com/biz/barcha-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Gastropubs', 'gastropubs'],
#     ['Venues & Event Spaces', 'venues']],
#    'display_phone': '+1-415-525-4335',
#    'id': 'myriad-gastropub-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bHXXEbxW7K1-_SMb9QKRmg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2491 Mission St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7572277060474,
#      'longitude': -122.418840453029},
#     'country_code': 'US',
#     'cross_streets': '21st St & 20th St',
#     'display_address': ['2491 Mission St',
#      'Mission',
#      'San Francisco, CA 94110'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Mission'],
#     'postal_code': '94110',
#     'state_code': 'CA'},
#    'menu_date_updated': 1477917563,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/myriad-gastropub-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Myriad Gastropub',
#    'phone': '4155254335',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 271,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/mb-jv2QWz6XupDywjhQ2ng/ms.jpg',
#    'snippet_text': 'After one bite of the fried chicken mini sliders, Myriad became an instant favorite. \n\nWe showed up on a busy Friday night without reservations, but were...',
#    'url': 'https://www.yelp.com/biz/myriad-gastropub-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Burmese', 'burmese']],
#    'display_phone': '+1-415-387-2147',
#    'id': 'burma-superstar-san-francisco-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nnDwAZSD38IxWtXlu3VGKg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['309 Clement St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.78289, 'longitude': -122.46253},
#     'country_code': 'US',
#     'cross_streets': '5th Ave & 4th Ave',
#     'display_address': ['309 Clement St',
#      'Inner Richmond',
#      'San Francisco, CA 94118'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Inner Richmond'],
#     'postal_code': '94118',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472584360,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/burma-superstar-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Burma Superstar',
#    'phone': '4153872147',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 5706,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/9nVSCd8GU68CGuxD0Cshug/ms.jpg',
#    'snippet_text': "I am always wary of places with a lot of hype because more often than not they don't live up to it and/or are not worth the long waits. Burma Superstar...",
#    'url': 'https://www.yelp.com/biz/burma-superstar-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Greek', 'greek'], ['Mediterranean', 'mediterranean']],
#    'display_phone': '+1-415-981-0983',
#    'id': 'kokkari-estiatorio-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hL5JQzUDA06eqvmUtdUqZA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['200 Jackson St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.797, 'longitude': -122.39988},
#     'country_code': 'US',
#     'cross_streets': 'Front St & Battery St',
#     'display_address': ['200 Jackson St',
#      'Financial District',
#      'San Francisco, CA 94111'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Financial District'],
#     'postal_code': '94111',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472590540,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/kokkari-estiatorio-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Kokkari Estiatorio',
#    'phone': '4159810983',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 3731,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/aCOdXhFeakgv-kGnRkSJpQ/ms.jpg',
#    'snippet_text': 'WOW THIS PLACE IS GREAT the shank was sooooooo good went here for a birthday and this just might be my new favorite restaurant \n\nFish is incredible and the...',
#    'url': 'https://www.yelp.com/biz/kokkari-estiatorio-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Hot Pot', 'hotpot'], ['Taiwanese', 'taiwanese']],
#    'display_phone': '+1-415-753-8788',
#    'id': 'lollipot-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/E3WlwavYodQJY828FiDEfg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['890 taraval st'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.74331, 'longitude': -122.47544},
#     'country_code': 'US',
#     'cross_streets': '19th Ave & 18th Ave',
#     'display_address': ['890 taraval st',
#      'Parkside',
#      'San Francisco, CA 94116'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Parkside'],
#     'postal_code': '94116',
#     'state_code': 'CA'},
#    'menu_date_updated': 1476770249,
#    'menu_provider': 'eat24',
#    'mobile_url': 'https://m.yelp.com/biz/lollipot-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Lollipot',
#    'phone': '4157538788',
#    'rating': 3.5,
#    'rating_img_url': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/5ef3eb3cb162/ico/stars/v1/stars_3_half.png',
#    'rating_img_url_large': 'https://s3-media3.fl.yelpcdn.com/assets/2/www/img/bd9b7a815d1b/ico/stars/v1/stars_large_3_half.png',
#    'rating_img_url_small': 'https://s3-media1.fl.yelpcdn.com/assets/2/www/img/2e909d5d3536/ico/stars/v1/stars_small_3_half.png',
#    'review_count': 101,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/6jw3GWfrY1ViCNZrMrMUVQ/ms.jpg',
#    'snippet_text': 'Thai Flavor Hot Soup\nSingapore Laksa Hot Soup\nJapanese Miso Hot Soup\nKorean Kimchi Hot Soup\n\nIf you cannot handle spice, mild is still pretty spicy. So far...',
#    'url': 'https://www.yelp.com/biz/lollipot-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Cafes', 'cafes'], ['Wine Bars', 'wine_bars']],
#    'display_phone': '+1-415-340-3967',
#    'id': 'orsons-belly-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FQ-vsKWVoLSgOAfGIrrV3A/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1737 Balboa St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.77646, 'longitude': -122.47773},
#     'country_code': 'US',
#     'cross_streets': '19th Ave & 18th Ave',
#     'display_address': ['1737 Balboa St',
#      'Outer Richmond',
#      'San Francisco, CA 94121'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Outer Richmond'],
#     'postal_code': '94121',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/orsons-belly-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "Orson's Belly",
#    'phone': '4153403967',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 32,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/Osmnggc3PX4XcjoSWZf8nA/ms.jpg',
#    'snippet_text': "This is my favourite cafe in the Richmond. By far. The service cannot be beat - the baristas are charming, efficient, and always happy to chat. They're also...",
#    'url': 'https://www.yelp.com/biz/orsons-belly-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Wine Bars', 'wine_bars'], ['Cafes', 'cafes']],
#    'display_phone': '+1-415-824-5524',
#    'id': 'noeteca-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dVWIkPAG2_4OJMk9FzS4Iw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1551 Dolores St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.74453, 'longitude': -122.42407},
#     'country_code': 'US',
#     'cross_streets': 'Valley St & 29th St',
#     'display_address': ['1551 Dolores St',
#      'Bernal Heights',
#      'San Francisco, CA 94110'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Bernal Heights', 'Mission'],
#     'postal_code': '94110',
#     'state_code': 'CA'},
#    'menu_date_updated': 1476088639,
#    'menu_provider': 'eat24',
#    'mobile_url': 'https://m.yelp.com/biz/noeteca-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Noeteca',
#    'phone': '4158245524',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 375,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/R4d_YeeCaJpmNhPQMAmhxQ/ms.jpg',
#    'snippet_text': 'Great food & service and no wait unlike tartine just up the street. Highly recommend their quiches!',
#    'url': 'https://www.yelp.com/biz/noeteca-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Dim Sum', 'dimsum'], ['Cantonese', 'cantonese']],
#    'display_phone': '+1-415-781-0721',
#    'id': 'delicious-dim-sum-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/47a_EutfnYi0F9RXQhJS2w/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['752 Jackson St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.796051, 'longitude': -122.4076004},
#     'country_code': 'US',
#     'cross_streets': 'Ross Aly & Duncombe Aly',
#     'display_address': ['752 Jackson St',
#      'Chinatown',
#      'San Francisco, CA 94133'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Chinatown'],
#     'postal_code': '94133',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/delicious-dim-sum-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Delicious Dim Sum',
#    'phone': '4157810721',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 658,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/qFSWxXEXRbgG-Q2RRHAweQ/ms.jpg',
#    'snippet_text': 'This is a little hole in the wall shop.  I got the shrimp dumplings and the shark fin dumplings. One order came with 3 pieces. Everything written on the...',
#    'url': 'https://www.yelp.com/biz/delicious-dim-sum-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Seafood', 'seafood'],
#     ['Japanese', 'japanese'],
#     ['Asian Fusion', 'asianfusion']],
#    'display_phone': '+1-415-255-8800',
#    'id': 'skool-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/47i057bRXAm_sIvA2obD5A/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1725 Alameda St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7685096967036,
#      'longitude': -122.402136325836},
#     'country_code': 'US',
#     'cross_streets': 'Rhode Island St',
#     'display_address': ['1725 Alameda St', 'SoMa', 'San Francisco, CA 94103'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['SoMa'],
#     'postal_code': '94103',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472769350,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/skool-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Skool',
#    'phone': '4152558800',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 1277,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/VmZAS6TTvWCKCegB_jfD9g/ms.jpg',
#    'snippet_text': 'Overall: 4.25.\n\nSquid ink spaghettina: 5.\n\nAnkimo mousse: 5.\n\nUni flan: 4.5.\n\nKaraage wings: 4.\n\nPacu BBQ ribs: 4 (novelty 5, flavor 3.5).\n\nBaby eryngii...',
#    'url': 'https://www.yelp.com/biz/skool-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Seafood', 'seafood'], ['Italian', 'italian']],
#    'display_phone': '+1-415-398-3181',
#    'id': 'sotto-mare-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A5sqbVpCIMqUdae_TSMkjQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['552 Green St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.79979, 'longitude': -122.40834},
#     'country_code': 'US',
#     'cross_streets': 'Columbus Ave & Stockton St',
#     'display_address': ['552 Green St',
#      'North Beach/Telegraph Hill',
#      'San Francisco, CA 94133'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['North Beach/Telegraph Hill'],
#     'postal_code': '94133',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472606906,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/sotto-mare-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Sotto Mare',
#    'phone': '4153983181',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 2531,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/Dg_7r6ZOrAgpTrsOdjfqcw/ms.jpg',
#    'snippet_text': 'The good was amazing! All four of us truly enjoyed our meal selections. I personally had the penne pasta with pesto and scallops and my goodness it was...',
#    'url': 'https://www.yelp.com/biz/sotto-mare-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Seafood', 'seafood'], ['Fish & Chips', 'fishnchips']],
#    'display_phone': '+1-415-437-2722',
#    'id': 'woodhouse-fish-company-san-francisco-3',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VW2sQJjK5czsG2ZPL18_zQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1914 Fillmore St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7874245926637, 'longitude': -122.4332785},
#     'country_code': 'US',
#     'cross_streets': 'Wilmot St & Bush St',
#     'display_address': ['1914 Fillmore St',
#      'Lower Pacific Heights',
#      'San Francisco, CA 94115'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Lower Pacific Heights'],
#     'postal_code': '94115',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472621868,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/woodhouse-fish-company-san-francisco-3?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Woodhouse Fish Company',
#    'phone': '4154372722',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 1790,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/z3lfT276sHYHhiFYPDM1_A/ms.jpg',
#    'snippet_text': 'Walk-ins only (no reservations).\n\nWhen we walked in at around 12:30pm on a rainy Sunday there were tons of tables, but by about 1pm, the restaurant was...',
#    'url': 'https://www.yelp.com/biz/woodhouse-fish-company-san-francisco-3?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Breakfast & Brunch', 'breakfast_brunch'],
#     ['American (New)', 'newamerican']],
#    'display_phone': '+1-415-821-7569',
#    'id': 'plow-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xwnpyICb7OMymxtw7v604g/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1299 18th St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.762537673684, 'longitude': -122.39535099572},
#     'country_code': 'US',
#     'cross_streets': 'Mississippi St & Texas St',
#     'display_address': ['1299 18th St',
#      'Potrero Hill',
#      'San Francisco, CA 94107'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Potrero Hill'],
#     'postal_code': '94107',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472701603,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/plow-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Plow',
#    'phone': '4158217569',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 1752,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/7ojyze-7kks4MjnZcCpnGQ/ms.jpg',
#    'snippet_text': "Baby you're my everything, you're all I ever wanted.. \n\nPlow, you da best I ever had.\n\nWhen a place is extra special you know I gotta throw in some Drake....",
#    'url': 'https://www.yelp.com/biz/plow-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Thai', 'thai'], ['Bars', 'bars']],
#    'display_phone': '+1-415-866-6337',
#    'id': 'tamarind-hall-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PPi-oQdTwwgMjFWzBxyfXA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1268 Grant Ave'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7986815225029,
#      'longitude': -122.407130934298},
#     'country_code': 'US',
#     'cross_streets': 'Vallejo St & Fresno St',
#     'display_address': ['1268 Grant Ave',
#      'North Beach/Telegraph Hill',
#      'San Francisco, CA 94133'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['North Beach/Telegraph Hill'],
#     'postal_code': '94133',
#     'state_code': 'CA'},
#    'menu_date_updated': 1476512076,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/tamarind-hall-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Tamarind Hall',
#    'phone': '4158666337',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 204,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/zwmOHvPXFUWscBMD16-bPw/ms.jpg',
#    'snippet_text': 'Me and my husband were in SF for the weekend.On the night we arrived we were hungry and was looking for a place to eat.We stumbled upon Tamarind Hall after...',
#    'url': 'https://www.yelp.com/biz/tamarind-hall-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Filipino', 'filipino']],
#    'display_phone': '+1-415-756-9844',
#    'id': 'fob-kitchen-san-francisco-4',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yBunQu_m3u53t7oOtoCVhw/ms.jpg',
#    'is_claimed': True,
# ...
#    'snippet_text': 'We used to go often to the Bistro SF Grill when it was located in Lower Pac Height and got to know the owner, Seni. He is a supremely kind, optimistic, and...',
#    'url': 'https://www.yelp.com/biz/bistro-sf-grill-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['American (Traditional)', 'tradamerican'],
#     ['Creperies', 'creperies'],
#     ['Breakfast & Brunch', 'breakfast_brunch']],
#    'display_phone': '+1-415-864-8484',
#    'id': '1428-haight-patio-cafe-and-crepery-san-francisco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-fbCg4q-0FMnCQ6ykZAJHg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['1428 Haight St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7701485211239,
#      'longitude': -122.445868540619},
#     'country_code': 'US',
#     'cross_streets': 'Masonic Ave & Ashbury St',
#     'display_address': ['1428 Haight St',
#      'The Haight',
#      'San Francisco, CA 94117'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['The Haight'],
#     'postal_code': '94117',
#     'state_code': 'CA'},
#    'menu_date_updated': 1474014042,
#    'menu_provider': 'eat24',
#    'mobile_url': 'https://m.yelp.com/biz/1428-haight-patio-cafe-and-crepery-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': '1428 HAIGHT Patio Cafe & Crepery',
#    'phone': '4158648484',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 172,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/319Ow_IHj5UnusV8SjuURA/ms.jpg',
#    'snippet_text': "Had the lox bagel and it was really good!! I love how they set it up as an open face sandwich so that it's kind of like we get to eat two thinner sandwich...",
#    'url': 'https://www.yelp.com/biz/1428-haight-patio-cafe-and-crepery-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Diners', 'diners'],
#     ['Breakfast & Brunch', 'breakfast_brunch'],
#     ['American (Traditional)', 'tradamerican']],
#    'display_phone': '+1-415-468-8805',
#    'id': 'breakfast-at-tiffanys-san-francisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2JclnVaTQFiczpFR4iuAcw/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2499 San Bruno Ave'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7304699, 'longitude': -122.40452},
#     'country_code': 'US',
#     'cross_streets': 'Thornton Ave & Felton St',
#     'display_address': ['2499 San Bruno Ave',
#      'Excelsior',
#      'San Francisco, CA 94134'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Excelsior', 'Portola'],
#     'postal_code': '94134',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/breakfast-at-tiffanys-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "Breakfast at Tiffany's",
#    'phone': '4154688805',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 573,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/VC_50mGsrcI6ehHJiAjweA/ms.jpg',
#    'snippet_text': "Solid food. Solid choices. \n\nThe name reminds me of the movie haha but i don't think it's in anyway related (correct me if I'm wrong)\n\nIn my opinion,...",
#    'url': 'https://www.yelp.com/biz/breakfast-at-tiffanys-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Asian Fusion', 'asianfusion'], ['Poke', 'poke']],
#    'display_phone': '+1-415-829-8030',
#    'id': 'ia-poke-san-francisco-2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/o65cLzv71isy_mt3Kz3_hQ/ms.jpg',
#    'is_claimed': False,
#    'is_closed': False,
#    'location': {'address': ['314 Church St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7657662812014,
#      'longitude': -122.429002347472},
#     'country_code': 'US',
#     'cross_streets': '16th St & 15th St',
#     'display_address': ['314 Church St', 'Castro', 'San Francisco, CA 94114'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Castro'],
#     'postal_code': '94114',
#     'state_code': 'CA'},
#    'mobile_url': 'https://m.yelp.com/biz/ia-poke-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "I'a Poke",
#    'phone': '4158298030',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 116,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/q5d5t3XsfT2snaB2jFRM3Q/ms.jpg',
#    'snippet_text': 'Star Rating 1-5\n\nStaff Friendliness: 5\nStaff Knowledge: 5\nStaff Efficiency: 5\nTransaction Time: 5\nOrder Wait Time: 5\nRegister Counter Cleanliness: 5\nKitchen...',
#    'url': 'https://www.yelp.com/biz/ia-poke-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Mexican', 'mexican']],
#    'display_phone': '+1-415-255-8225',
#    'id': 'the-little-chihuahua-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HEeHex4LPIssbDQtTJJIjQ/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['292 Divisadero St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7720399, 'longitude': -122.43688},
#     'country_code': 'US',
#     'cross_streets': 'Haight St & Page St',
#     'display_address': ['292 Divisadero St',
#      'Lower Haight',
#      'San Francisco, CA 94117'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Lower Haight'],
#     'postal_code': '94117',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472612542,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/the-little-chihuahua-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'The Little Chihuahua',
#    'phone': '4152558225',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 1319,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/fy26V-B79kL9bnC1RIvM7g/ms.jpg',
#    'snippet_text': "Holy smokes. Set aside authentic because I can't be a great judge of that. This place is delicious! A little pricier than I was expecting, but after eating...",
#    'url': 'https://www.yelp.com/biz/the-little-chihuahua-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['American (New)', 'newamerican'],
#     ['Breakfast & Brunch', 'breakfast_brunch']],
#    'display_phone': '+1-415-861-0198',
#    'id': 'mission-beach-cafe-san-francisco-4',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yqvibbFkj-p_m_FRNy_Dkg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['198 Guerrero St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7680853025175,
#      'longitude': -122.424638201818},
#     'country_code': 'US',
#     'cross_streets': 'Brosnan St & 14th St',
#     'display_address': ['198 Guerrero St',
#      'Mission',
#      'San Francisco, CA 94103'],
#     'geo_accuracy': 9.5,
#     'neighborhoods': ['Mission'],
#     'postal_code': '94103',
#     'state_code': 'CA'},
#    'menu_date_updated': 1474344547,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/mission-beach-cafe-san-francisco-4?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Mission Beach Cafe',
#    'phone': '4158610198',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 2318,
#    'snippet_image_url': 'https://s3-media3.fl.yelpcdn.com/photo/fsx_E-zWQI4ksDqCuPH1Vw/ms.jpg',
#    'snippet_text': "The mushroom egg benedicts ARE SOOOOO GOOD!!! Especially with the sweet and savory bacon on them, don't skimp on the bacon addition! I've had my share of...",
#    'url': 'https://www.yelp.com/biz/mission-beach-cafe-san-francisco-4?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Vietnamese', 'vietnamese']],
#    'display_phone': '+1-415-795-1469',
#    'id': 'dragoneats-san-francisco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IrXcbnBs-LaoFxlk0N0iPg/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['520 Gough St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7784199, 'longitude': -122.42292},
#     'country_code': 'US',
#     'cross_streets': 'Grove St & Fulton St',
#     'display_address': ['520 Gough St',
#      'Hayes Valley',
#      'San Francisco, CA 94102'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Hayes Valley'],
#     'postal_code': '94102',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472759172,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/dragoneats-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'DragonEats',
#    'phone': '4157951469',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 236,
#    'snippet_image_url': 'https://s3-media1.fl.yelpcdn.com/photo/daiHx0N9QPUNJZ1lbVNjgw/ms.jpg',
#    'snippet_text': 'Cheap. Fresh. Delicious. \n\nPork Banh Mi Sandwich:\nBread was crisp and toasty but not hard. Veggies were fresh and clean. Meat was soft and flavorful....',
#    'url': 'https://www.yelp.com/biz/dragoneats-san-francisco?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Austrian', 'austrian'], ['Bars', 'bars']],
#    'display_phone': '+1-415-474-2000',
#    'id': 'leopolds-san-francisco-2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/K7XMJrigGsnrLu538UimJA/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['2400 Polk St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7989197, 'longitude': -122.4220734},
#     'country_code': 'US',
#     'cross_streets': 'Union St & Filbert St',
#     'display_address': ['2400 Polk St',
#      'Russian Hill',
#      'San Francisco, CA 94109'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Russian Hill'],
#     'postal_code': '94109',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472724091,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/leopolds-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': "Leopold's",
#    'phone': '4154742000',
#    'rating': 4.5,
#    'rating_img_url': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/99493c12711e/ico/stars/v1/stars_4_half.png',
#    'rating_img_url_large': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/9f83790ff7f6/ico/stars/v1/stars_large_4_half.png',
#    'rating_img_url_small': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/a5221e66bc70/ico/stars/v1/stars_small_4_half.png',
#    'review_count': 871,
#    'snippet_image_url': 'https://s3-media4.fl.yelpcdn.com/photo/dTh6JQGdzwA6bxIftWqRgQ/ms.jpg',
#    'snippet_text': 'Real food, forget about all the other places that claims yto serve german food around the town. You get the best schnitzel here, even when it is not a...',
#    'url': 'https://www.yelp.com/biz/leopolds-san-francisco-2?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'},
#   {'categories': [['Japanese', 'japanese'],
#     ['Korean', 'korean'],
#     ['Asian Fusion', 'asianfusion']],
#    'display_phone': '+1-415-463-5085',
#    'id': 'koja-kitchen-san-francisco-7',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VXWBx_QVZKL-uqUIe2H95g/ms.jpg',
#    'is_claimed': True,
#    'is_closed': False,
#    'location': {'address': ['343 Clement St'],
#     'city': 'San Francisco',
#     'coordinate': {'latitude': 37.7828615, 'longitude': -122.4631065},
#     'country_code': 'US',
#     'cross_streets': '5th Ave & 4th Ave',
#     'display_address': ['343 Clement St',
#      'Inner Richmond',
#      'San Francisco, CA 94118'],
#     'geo_accuracy': 8.0,
#     'neighborhoods': ['Inner Richmond'],
#     'postal_code': '94118',
#     'state_code': 'CA'},
#    'menu_date_updated': 1472897117,
#    'menu_provider': 'single_platform',
#    'mobile_url': 'https://m.yelp.com/biz/koja-kitchen-san-francisco-7?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug',
#    'name': 'Koja Kitchen',
#    'phone': '4154635085',
#    'rating': 4.0,
#    'rating_img_url': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/c2f3dd9799a5/ico/stars/v1/stars_4.png',
#    'rating_img_url_large': 'https://s3-media2.fl.yelpcdn.com/assets/2/www/img/ccf2b76faa2c/ico/stars/v1/stars_large_4.png',
#    'rating_img_url_small': 'https://s3-media4.fl.yelpcdn.com/assets/2/www/img/f62a5be2f902/ico/stars/v1/stars_small_4.png',
#    'review_count': 300,
#    'snippet_image_url': 'https://s3-media2.fl.yelpcdn.com/photo/5MmbhHj1y9Hcz2Jr4Dh1Hw/ms.jpg',
#    'snippet_text': "Never had Koja before, but I was an instant fan. \nHere's what I've tried so far:\n\n- Egg Koja = my favorite. Absolutely delicious. Not listed on the regular...",
#    'url': 'https://www.yelp.com/biz/koja-kitchen-san-francisco-7?adjust_creative=CQ0SBNGlDITRbkw2PM84Ug&utm_campaign=yelp_api&utm_medium=api_v2_search&utm_source=CQ0SBNGlDITRbkw2PM84Ug'}],
#  'region': {'center': {'latitude': 37.765116649999996,
#    'longitude': -122.43657064786},
#   'span': {'latitude_delta': 0.07629875000000652,
#    'longitude_delta': 0.09068323470799555}},
#  'total': 8327}

# %%
for i in range(len(v)):
    for j in range(len(v[i]['businesses'])):
           data.append(v[i]['businesses'][j])

# %%
temp[10]
# Out:
# 'electric-tour-company-san-francisco-9'

# %%
len(data)
# Out:
# 558

# %%
for i in range(len(data)):
    temp.append(data[i]['id'])

# %%
for i in range(300):
    temp.append(data[i]['id'])

# %%
new=[]

# %%
for i in range(len(temp)):
    new.append(requests.get('https://api.yelp.com/v3/businesses/'+temp[i],headers=headers).json())

# %%
len(new)
# Out:
# 558

# %%
requests.get('https://api.yelp.com/v3/businesses/'+temp[0],headers=headers).json()
# Out:
# {'categories': [{'alias': 'indpak', 'title': 'Indian'},
#   {'alias': 'himalayan', 'title': 'Himalayan/Nepalese'},
#   {'alias': 'halal', 'title': 'Halal'}],
#  'coordinates': {'latitude': 37.7847215, 'longitude': -122.4130263},
#  'hours': [{'hours_type': 'REGULAR',
#    'is_open_now': True,
#    'open': [{'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#     {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#     {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#     {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#     {'day': 4, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#     {'day': 5, 'end': '2200', 'is_overnight': False, 'start': '1100'},
#     {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1100'}]}],
#  'id': 'newa-san-francisco-4',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZH5UKs6hZfo2QWCy9k85Yg/o.jpg',
#  'is_claimed': True,
#  'is_closed': False,
#  'location': {'address1': '407 Ellis St',
#   'address2': '',
#   'address3': None,
#   'city': 'San Francisco',
#   'country': 'US',
#   'state': 'CA',
#   'zip_code': '94102'},
#  'name': 'Newa',
#  'phone': '+14154473876',
#  'photos': ['https://s3-media1.fl.yelpcdn.com/bphoto/ZH5UKs6hZfo2QWCy9k85Yg/o.jpg',
#   'https://s3-media2.fl.yelpcdn.com/bphoto/IRyreD393XL6lDMJRTWqZA/o.jpg',
#   'https://s3-media4.fl.yelpcdn.com/bphoto/hqrDfLlpUocAOeWuFhmhBw/o.jpg'],
#  'price': '$$',
#  'rating': 4.0,
#  'review_count': 49,
#  'url': 'https://www.yelp.com/biz/newa-san-francisco-4?adjust_creative=92p07_JjKyriZTQxAXRiKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=92p07_JjKyriZTQxAXRiKQ'}

# %%
import json
for i in range(len(new)):
    with open('D:\\Yelp\\San Francisco\\Popular Spots'+'\\'+new[i]['id']+'.json', 'w') as outfile:
        json.dump(new[i], outfile)

# %%
temp[500]
# Out:
# 'exotic-getaway-travel-san-francisco-2'

# %%
len(new)
# Out:
# 442

# %%
//Spotify

# %%
uauth = OAuth1('CQ0SBNGlDITRbkw2PM84Ug', '7RVaHKptMjqId0CaOSIS_5mnW84',
                  'WmOCoc8PHkdfsDOWv7vnVD2fiOTkstxO', '_yYDR4Kh2qq0tsup11JfS9xzxqU')

# %%
url='https://accounts.spotify.com/api/token'
body_params = {'grant_type' : 'client_credentials'}

response=requests.post(url, data=body_params, auth = ('ecc01f44745f45d0bedc43b8b4ee7e40', '7c5f80b068ec4c3086f4eacd35db833a')).json() 
print (response)
# Out:
# {'token_type': 'Bearer', 'expires_in': 3600, 'access_token': 'BQDFTdqpmPr5YXQd3Hi9PS88i9zoh1JKL4TroyXsGpbTamUzltD0Y8pk9y-skQGVZ8UTatXhzMuxfdxLpyeSjw'}

# %%
response['access_token']
# Out:
# 'BQDFTdqpmPr5YXQd3Hi9PS88i9zoh1JKL4TroyXsGpbTamUzltD0Y8pk9y-skQGVZ8UTatXhzMuxfdxLpyeSjw'

# %%
headerss = {
       'Authorization': 'Bearer %s' % response['access_token']
}

# %%
headerss
# Out:
# {'Authorization': 'Bearer BQDFTdqpmPr5YXQd3Hi9PS88i9zoh1JKL4TroyXsGpbTamUzltD0Y8pk9y-skQGVZ8UTatXhzMuxfdxLpyeSjw'}

# %%
requests.get('https://api.spotify.com/v1/browse/new-releases',headers=headerss).json()
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TR',
#      'TW',
#      'UY'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/09fggMHib4YkOtwQNXEBII'},
#     'href': 'https://api.spotify.com/v1/albums/09fggMHib4YkOtwQNXEBII',
#     'id': '09fggMHib4YkOtwQNXEBII',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/2c7ef91e8327dec51919d1f3be37a411b4028306',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4816c45ce6ef1e45df6a84784d2123595f787182',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a2c3947510abbeb764603aa53b96b33d97bd3ff0',
#       'width': 64}],
#     'name': 'Starboy',
#     'type': 'album',
#     'uri': 'spotify:album:09fggMHib4YkOtwQNXEBII'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5y2Xq6xcjJb2jVM54GHK3t'},
#       'href': 'https://api.spotify.com/v1/artists/5y2Xq6xcjJb2jVM54GHK3t',
#       'id': '5y2Xq6xcjJb2jVM54GHK3t',
#       'name': 'John Legend',
#       'type': 'artist',
#       'uri': 'spotify:artist:5y2Xq6xcjJb2jVM54GHK3t'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3ln7gtD4aGjJWllmL1Uqij'},
#     'href': 'https://api.spotify.com/v1/albums/3ln7gtD4aGjJWllmL1Uqij',
#     'id': '3ln7gtD4aGjJWllmL1Uqij',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e9ed80f470af1f7b8d53a80f7dd64f4d81ff30f2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/f9e1ce6a1970a357dad922ce7de0ef7b4ad16124',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/35e8bc74390f06ac1e5f3283e8bf1da100231ea6',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:3ln7gtD4aGjJWllmL1Uqij'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M0lbkGluOPXLeFjApw8r8'},
#       'href': 'https://api.spotify.com/v1/artists/5M0lbkGluOPXLeFjApw8r8',
#       'id': '5M0lbkGluOPXLeFjApw8r8',
#       'name': 'D.R.A.M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:5M0lbkGluOPXLeFjApw8r8'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1N7l9Oc5FiLQhqQ7mJ66bm'},
#     'href': 'https://api.spotify.com/v1/albums/1N7l9Oc5FiLQhqQ7mJ66bm',
#     'id': '1N7l9Oc5FiLQhqQ7mJ66bm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/953f9fb872345380caf71fcd284b65e2ad99c7fe',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/3582108cd027fdf3d896543ce5588a4a24f69c4f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/fc2ab41a7b2eccd81ad336e8cbf934b156eef1d9',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:1N7l9Oc5FiLQhqQ7mJ66bm'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NHQUGzhtTLFvgF5SZesLK'},
#       'href': 'https://api.spotify.com/v1/artists/4NHQUGzhtTLFvgF5SZesLK',
#       'id': '4NHQUGzhtTLFvgF5SZesLK',
#       'name': 'Tove Lo',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NHQUGzhtTLFvgF5SZesLK'}],
#     'available_markets': ['CA', 'US', 'MX'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FOhbAW6X74onlLJOTNIjD'},
#     'href': 'https://api.spotify.com/v1/albums/6FOhbAW6X74onlLJOTNIjD',
#     'id': '6FOhbAW6X74onlLJOTNIjD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c200097cc49b9e89046843ba75e7d2c12147f1af',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6a8a34e897536c2a6a54be43e349a816a57e6119',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/e8a6d2336caae54ca5b7ca0734521d68938491f4',
#       'width': 64}],
#     'name': 'Spotify Singles (Recorded At Spotify, NYC)',
#     'type': 'album',
#     'uri': 'spotify:album:6FOhbAW6X74onlLJOTNIjD'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UWZUmn7sybxMCqrw9tGa7'},
#       'href': 'https://api.spotify.com/v1/artists/0UWZUmn7sybxMCqrw9tGa7',
#       'id': '0UWZUmn7sybxMCqrw9tGa7',
#       'name': 'Juanes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0UWZUmn7sybxMCqrw9tGa7'}],
#     'available_markets': ['CA', 'US', 'MX'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ouh1shN9w3s7NzrW1sIDX'},
#     'href': 'https://api.spotify.com/v1/albums/2ouh1shN9w3s7NzrW1sIDX',
#     'id': '2ouh1shN9w3s7NzrW1sIDX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/7061f6ca71c078db541c8cf30f3dcc30dc020481',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2e87909188593412dcd5c8d20f71a8e67492106e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/fd18ce96ed68c8457ad0598f8745b71fc571db0f',
#       'width': 64}],
#     'name': 'Spotify Singles (Recorded At Spotify Studios NYC)',
#     'type': 'album',
#     'uri': 'spotify:album:2ouh1shN9w3s7NzrW1sIDX'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bepW5vcdRzheNc0F8lHJ5'},
#       'href': 'https://api.spotify.com/v1/artists/5bepW5vcdRzheNc0F8lHJ5',
#       'id': '5bepW5vcdRzheNc0F8lHJ5',
#       'name': 'Esperanza Spalding',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bepW5vcdRzheNc0F8lHJ5'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3iLgafL3t8zorpB18bKfzF'},
#     'href': 'https://api.spotify.com/v1/albums/3iLgafL3t8zorpB18bKfzF',
#     'id': '3iLgafL3t8zorpB18bKfzF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/6816b9069f3e4ad3e04075a96f2cff7a498423ee',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ac01a482689c5d8c847232b2c09caf344ce5107e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0991407fa5b52996e122f77d38a2678a644c65a8',
#       'width': 64}],
#     'name': 'Spotify Singles (Recorded At Spotify Studios NYC)',
#     'type': 'album',
#     'uri': 'spotify:album:3iLgafL3t8zorpB18bKfzF'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25oLRSUjJk4YHNUsQXk7Ut'},
#       'href': 'https://api.spotify.com/v1/artists/25oLRSUjJk4YHNUsQXk7Ut',
#       'id': '25oLRSUjJk4YHNUsQXk7Ut',
#       'name': 'GRiZ',
#       'type': 'artist',
#       'uri': 'spotify:artist:25oLRSUjJk4YHNUsQXk7Ut'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4ma8f0czTWlb6WKXpsuykT'},
#     'href': 'https://api.spotify.com/v1/albums/4ma8f0czTWlb6WKXpsuykT',
#     'id': '4ma8f0czTWlb6WKXpsuykT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b6c4d10ccc63648f1c0aa98cd44b711ee3f38e0b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/23198a56c56f3381ff3eefe3aca75ac3787e9f97',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/73f376ff782654d4cd6ab7ca6fed9ae546e446dc',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:4ma8f0czTWlb6WKXpsuykT'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kVUvbeRdcrqQ3oHk5hPdx'},
#       'href': 'https://api.spotify.com/v1/artists/3kVUvbeRdcrqQ3oHk5hPdx',
#       'id': '3kVUvbeRdcrqQ3oHk5hPdx',
#       'name': 'Grouplove',
#       'type': 'artist',
#       'uri': 'spotify:artist:3kVUvbeRdcrqQ3oHk5hPdx'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0uneTqrqMeF49ETtLvVOcl'},
#     'href': 'https://api.spotify.com/v1/albums/0uneTqrqMeF49ETtLvVOcl',
#     'id': '0uneTqrqMeF49ETtLvVOcl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/edfbd7d337358bbaf755e4f4e86c12137acfaf20',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/f489bbc103947ea92ed30a3fc64c07f7b54c54af',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/c04a05182ecd535e1dc5ea511d6132e55d20087d',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:0uneTqrqMeF49ETtLvVOcl'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SqTiwOEdYrNayaGMkc7ia'},
#       'href': 'https://api.spotify.com/v1/artists/4SqTiwOEdYrNayaGMkc7ia',
#       'id': '4SqTiwOEdYrNayaGMkc7ia',
#       'name': 'LÉON',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SqTiwOEdYrNayaGMkc7ia'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Kvg9h8w3OMPNkDISwcal8'},
#     'href': 'https://api.spotify.com/v1/albums/3Kvg9h8w3OMPNkDISwcal8',
#     'id': '3Kvg9h8w3OMPNkDISwcal8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/93fc8d5f4efbc54eef819fecbe872c1bac093cc4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/50a0f651be8a8ddd5efb700e546aa8487c7bd5b0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/572323faff4a466fe1e0448332d495a63224a9ed',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:3Kvg9h8w3OMPNkDISwcal8'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3h0w83PsjASrm5999trG4n'},
#       'href': 'https://api.spotify.com/v1/artists/3h0w83PsjASrm5999trG4n',
#       'id': '3h0w83PsjASrm5999trG4n',
#       'name': 'Hamilton Leithauser + Rostam',
#       'type': 'artist',
#       'uri': 'spotify:artist:3h0w83PsjASrm5999trG4n'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZXXJ9nO1Dn9B0AJ25eAQY'},
#       'href': 'https://api.spotify.com/v1/artists/3ZXXJ9nO1Dn9B0AJ25eAQY',
#       'id': '3ZXXJ9nO1Dn9B0AJ25eAQY',
#       'name': 'Hamilton Leithauser',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ZXXJ9nO1Dn9B0AJ25eAQY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/04XggbrM51GcFPTxBYtRXT'},
#       'href': 'https://api.spotify.com/v1/artists/04XggbrM51GcFPTxBYtRXT',
#       'id': '04XggbrM51GcFPTxBYtRXT',
#       'name': 'Rostam',
#       'type': 'artist',
#       'uri': 'spotify:artist:04XggbrM51GcFPTxBYtRXT'}],
#     'available_markets': ['CA', 'US', 'MX'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0XyEzOV3gsUwkCjuFdxD47'},
#     'href': 'https://api.spotify.com/v1/albums/0XyEzOV3gsUwkCjuFdxD47',
#     'id': '0XyEzOV3gsUwkCjuFdxD47',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/073b6ef85455cdab692bf85845df0cf629bcb510',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/9de479d46c4db6b6eac6f18f0e15ce930016594c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/5a5dc6a3d3c3bd7f0cf103d3ad85a52e84028ae0',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:0XyEzOV3gsUwkCjuFdxD47'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4uSftVc3FPWe6RJuMZNEe9'},
#       'href': 'https://api.spotify.com/v1/artists/4uSftVc3FPWe6RJuMZNEe9',
#       'id': '4uSftVc3FPWe6RJuMZNEe9',
#       'name': 'Andrew Bird',
#       'type': 'artist',
#       'uri': 'spotify:artist:4uSftVc3FPWe6RJuMZNEe9'}],
#     'available_markets': ['CA', 'US', 'MX'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5o5o3S9tQZN6jWgCdOk0d2'},
#     'href': 'https://api.spotify.com/v1/albums/5o5o3S9tQZN6jWgCdOk0d2',
#     'id': '5o5o3S9tQZN6jWgCdOk0d2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e00868d60e001e20ffd4e6f751967580e4a094be',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/19a0ad72e5df4dbf1460379123df1b15f5c23167',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/58780ca3d9b98ab5be382a46c724613613c6ebf6',
#       'width': 64}],
#     'name': 'Spotify Singles (Recorded At Spotify Studios NYC)',
#     'type': 'album',
#     'uri': 'spotify:album:5o5o3S9tQZN6jWgCdOk0d2'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1M3BVQ36cqPQix8lQNCh4K'},
#       'href': 'https://api.spotify.com/v1/artists/1M3BVQ36cqPQix8lQNCh4K',
#       'id': '1M3BVQ36cqPQix8lQNCh4K',
#       'name': 'Shovels & Rope',
#       'type': 'artist',
#       'uri': 'spotify:artist:1M3BVQ36cqPQix8lQNCh4K'}],
#     'available_markets': ['AR',
#      'AU',
#      'BR',
#      'CL',
#      'HK',
#      'ID',
#      'JP',
#      'MY',
#      'NZ',
#      'PH',
#      'PY',
#      'SG',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6vF9azZbi8E19Vw48hdtaB'},
#     'href': 'https://api.spotify.com/v1/albums/6vF9azZbi8E19Vw48hdtaB',
#     'id': '6vF9azZbi8E19Vw48hdtaB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9939ca4c1f34b69880894cdbcca666d21c80b353',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/32f3ecc2d3d436cf4164d8633f5a9cdffe007423',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2d57c687e3b760cb62e9112aaa8e7898bd4ba29f',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:6vF9azZbi8E19Vw48hdtaB'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oqwwcM17wrP9hBD25zKSR'},
#       'href': 'https://api.spotify.com/v1/artists/2oqwwcM17wrP9hBD25zKSR',
#       'id': '2oqwwcM17wrP9hBD25zKSR',
#       'name': 'Lewis Del Mar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2oqwwcM17wrP9hBD25zKSR'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3mAukfV30IyEPuX6ZxOgCq'},
#     'href': 'https://api.spotify.com/v1/albums/3mAukfV30IyEPuX6ZxOgCq',
#     'id': '3mAukfV30IyEPuX6ZxOgCq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/6bca20c6558feb93c646466f17a651541b2a0189',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6e6b9c949b628dd9cae56db14b069648213005fe',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/51008445b813a1c4461c22a803c66771d81f6f55',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:3mAukfV30IyEPuX6ZxOgCq'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uikSah4dwqwuk0EidFI4R'},
#       'href': 'https://api.spotify.com/v1/artists/3uikSah4dwqwuk0EidFI4R',
#       'id': '3uikSah4dwqwuk0EidFI4R',
#       'name': 'Caitlyn Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:3uikSah4dwqwuk0EidFI4R'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3BtaYjFyAb4GmZ6qJxtiTr'},
#     'href': 'https://api.spotify.com/v1/albums/3BtaYjFyAb4GmZ6qJxtiTr',
#     'id': '3BtaYjFyAb4GmZ6qJxtiTr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a103c989ec7b414b378f8692d08fefe549018b7c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/7a689a6751128105e5fef044ace5da09df358e81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/6fdc283db9456b4b6cd1719810b9190bdc894714',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:3BtaYjFyAb4GmZ6qJxtiTr'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4wYk01oPJNfaEssVFL46oQ'},
#       'href': 'https://api.spotify.com/v1/artists/4wYk01oPJNfaEssVFL46oQ',
#       'id': '4wYk01oPJNfaEssVFL46oQ',
#       'name': 'Coast Modern',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wYk01oPJNfaEssVFL46oQ'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4jdJSsxnZM4RbRxxJ8TO9L'},
#     'href': 'https://api.spotify.com/v1/albums/4jdJSsxnZM4RbRxxJ8TO9L',
#     'id': '4jdJSsxnZM4RbRxxJ8TO9L',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/7a4f0b73cfcf78044dc71c1e1c7c3ecc400250cf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/cf3ecead731c7ae4433d5d02cb70630e3aee5c0a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a7c4d71ba16a98c1a0890a1b28f21c166d03692b',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:4jdJSsxnZM4RbRxxJ8TO9L'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/75dQReiBOHN37fQgWQrIAJ'},
#       'href': 'https://api.spotify.com/v1/artists/75dQReiBOHN37fQgWQrIAJ',
#       'id': '75dQReiBOHN37fQgWQrIAJ',
#       'name': 'Local Natives',
#       'type': 'artist',
#       'uri': 'spotify:artist:75dQReiBOHN37fQgWQrIAJ'}],
#     'available_markets': ['CA', 'US', 'MX'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2pmZrbCbPmu1tKnABQTumb'},
#     'href': 'https://api.spotify.com/v1/albums/2pmZrbCbPmu1tKnABQTumb',
#     'id': '2pmZrbCbPmu1tKnABQTumb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b856e193e006a6d74da44353682b4e06d4424418',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2cb320dbc0c37017ad3e33ee08c2059a6db2e6d5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/af9d82b816e1d63237b924fc54354ca3adf5957f',
#       'width': 64}],
#     'name': 'Spotify Singles (Recorded At Spotify Studios NYC)',
#     'type': 'album',
#     'uri': 'spotify:album:2pmZrbCbPmu1tKnABQTumb'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13YVfXddjRIUrubItJjadb'},
#       'href': 'https://api.spotify.com/v1/artists/13YVfXddjRIUrubItJjadb',
#       'id': '13YVfXddjRIUrubItJjadb',
#       'name': 'Margaret Glaspy',
#       'type': 'artist',
#       'uri': 'spotify:artist:13YVfXddjRIUrubItJjadb'}],
#     'available_markets': ['US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3JbrnUMiO5gRtb5jOxEk8r'},
#     'href': 'https://api.spotify.com/v1/albums/3JbrnUMiO5gRtb5jOxEk8r',
#     'id': '3JbrnUMiO5gRtb5jOxEk8r',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b6d5b0947723cb18f989f917e70f067f9d10ce13',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5fb2b2034bbb949a7f0b0a688c7c758700861040',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ddf257f4d1808fa9340ef46f201683ab67c0503d',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:3JbrnUMiO5gRtb5jOxEk8r'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6miuYP0AovZaaKpRFaDQMQ'},
#       'href': 'https://api.spotify.com/v1/artists/6miuYP0AovZaaKpRFaDQMQ',
#       'id': '6miuYP0AovZaaKpRFaDQMQ',
#       'name': 'Spencer Ludwig',
#       'type': 'artist',
#       'uri': 'spotify:artist:6miuYP0AovZaaKpRFaDQMQ'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0bRsCrUAjvQeQZGLrDFesT'},
#     'href': 'https://api.spotify.com/v1/albums/0bRsCrUAjvQeQZGLrDFesT',
#     'id': '0bRsCrUAjvQeQZGLrDFesT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e5b09873acef054ca8cbb1c30dd6a333d73be6dc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/74e1ad088b869bd81b939e5cfaf0adfd6e7b81e1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ff2d71f9e8912b3b128f677c9d78c1e0ea6bf2c3',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:0bRsCrUAjvQeQZGLrDFesT'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oeUpvxWsC8bWS6SnpU8b9'},
#       'href': 'https://api.spotify.com/v1/artists/0oeUpvxWsC8bWS6SnpU8b9',
#       'id': '0oeUpvxWsC8bWS6SnpU8b9',
#       'name': 'The Naked And Famous',
#       'type': 'artist',
#       'uri': 'spotify:artist:0oeUpvxWsC8bWS6SnpU8b9'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ospU0wa9ux7r054JMFbEL'},
#     'href': 'https://api.spotify.com/v1/albums/2ospU0wa9ux7r054JMFbEL',
#     'id': '2ospU0wa9ux7r054JMFbEL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/74ec3264f6e0863bd180cc717ea005bac2d656d4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5cb2c91caa0da612f2c079855b9f831d23680c94',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/8356d0d1afd6c2ded8fad46071fa734aed5d0cc8',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:2ospU0wa9ux7r054JMFbEL'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/378dH6EszOLFShpRzAQkVM'},
#       'href': 'https://api.spotify.com/v1/artists/378dH6EszOLFShpRzAQkVM',
#       'id': '378dH6EszOLFShpRzAQkVM',
#       'name': 'Lindsey Stirling',
#       'type': 'artist',
#       'uri': 'spotify:artist:378dH6EszOLFShpRzAQkVM'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BR',
#      'CH',
#      'CL',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HK',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'TR',
#      'TW',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1XXSHevNKbENDXqH5iRSEC'},
#     'href': 'https://api.spotify.com/v1/albums/1XXSHevNKbENDXqH5iRSEC',
#     'id': '1XXSHevNKbENDXqH5iRSEC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/1d402f76b664f9cdc57a5fa4329650b1c7d479c6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/693a1939a032a8da7914fc23888a3536bbf41a9b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b414020d9f7a4d4766756c33dfd5224586790964',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'type': 'album',
#     'uri': 'spotify:album:1XXSHevNKbENDXqH5iRSEC'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 500}}
